# %% [markdown]
# # This is a TF Estimator end-to-end baseline solution
#
# **For local run**
#
# Tested with
#
# ```
# numpy==1.13.3
# scipy==0.19.1
# tensorflow-gpu==1.4.0
# tqdm
# ```
#
#
# I want to show usage of Estimators with custom python datagenerators.
#
#
# Detailed documentation you can find at https://www.tensorflow.org/api_docs/python/tf/estimator/Estimator
#
# I also recommend to read source code  https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/estimator/estimator.py

# %% [markdown]
# Suppose we have following project structure:
# ```
# .
# ├── data
# │   ├── test            # extracted
# │   │   └── audio          # all test
# │   ├── test.7z         # downloaded
# │   ├── train           # extracted
# │   │   ├── audio          # folder with all train command/file.wav
# │   │   ├── LICENSE
# │   │   ├── README.md
# │   │   ├── testing_list.txt
# │   │   └── validation_list.txt
# │   └── train.7z         # downloaded
# ├── kernel.ipynb      # this ipynb
# └── model-k           # folder for model, checkpoints, logs and submission.csv
# ```

# %%
DATADIR = '../data' # unzipped train and test data
OUTDIR = './model-k' # just a random name
# Data Loading
import os
import re
from glob import glob


POSSIBLE_LABELS = 'yes no up down left right on off stop go silence unknown'.split()
id2name = {i: name for i, name in enumerate(POSSIBLE_LABELS)}
name2id = {name: i for i, name in id2name.items()}


def load_data(data_dir):
    """ Return 2 lists of tuples:
    [(class_id, user_id, path), ...] for train
    [(class_id, user_id, path), ...] for validation
    """
    # Just a simple regexp for paths with three groups:
    # prefix, label, user_id
    pattern = re.compile("(.+\/)?(\w+)\/([^_]+)_.+wav")
    all_files = glob(os.path.join(data_dir, 'train/audio/*/*wav'))

    with open(os.path.join(data_dir, 'train/validation_list.txt'), 'r') as fin:
        validation_files = fin.readlines()
    valset = set()
    for entry in validation_files:
        r = re.match(pattern, entry)
        if r:
            valset.add(r.group(3))

    print(valset)
    possible = set(POSSIBLE_LABELS)
    print(possible)
    train, val = [], []
    for entry in all_files:
        entry = entry.replace('\\', '/')
        r = re.match(pattern, entry)
        if r:
            label, uid = r.group(2), r.group(3)
            if label == '_background_noise_':
                label = 'silence'
            if label not in possible:
                label = 'unknown'
            
            label_id = name2id[label]

            sample = (label_id, uid, entry)
            if uid in valset:
                val.append(sample)
            else:
                train.append(sample)

    print('There are {} train and {} val samples'.format(len(train), len(val)))
    return train, val

trainset, valset = load_data(DATADIR)
# Out:
# {'4abefdf5', '8843b25f', 'c24d96eb', '591d32f3', 'fd32732a', 'b0f24c9b', 'ec74a8a5', '86478fab', 'fc94edb0', 'c842b5e4', 'ab1299bb', '7c1d8533', 'fde2dee7', 'f84762e5', '9db2bfe9', '2643992f', '7be5a0f3', 'd8d12371', '7fd25f7c', '16db1582', 'b5d1e505', '794cdfc5', '2296b1af', 'd197e3ae', '41285056', '2ce7534c', '66774579', '7ca023e2', '8910e5ef', '86402da1', '52e228e9', '6c0f6493', 'c256377f', '88f8a99c', 'a1dd919f', '6a27a9bf', 'bfbd0e6b', 'cc6bae0d', '638685f2', 'b0c0197e', '3e2ba5f7', '409c962a', '7195ffa6', '605ed0ff', '439c84f4', 'd57febf0', 'c4e1f6e0', '2a89ad5c', 'dbaf8fc6', '826268f8', 'eb0857c0', 'd9ae8983', '97ae8b25', '6d0ad764', '44c201dd', 'db43cd03', '65ec06e5', 'ae927455', 'db4cf12f', 'c6389ab0', '026290a7', 'c6ee87a7', 'e6db3894', '52bfbce8', 'c50225fa', 'bdee441c', '27b9a84f', 'e8c3c5ca', 'b7016c27', '258f4559', '105e72bb', 'dd086776', 'd55aa56c', '099d52ad', 'f9ebdba0', '50f55535', '7117fb6d', 'b6ebe225', 'f3cee168', 'edc53350', '53d5b86f', '9cde5de8', 'b1edd209', '44bc77f7', '22aa3665', '5fadb538', 'ccea893d', '8523766b', '541120c7', 'a7dd45cf', '67c7fecb', 'f17be97f', '3903b558', '48bfde8e', '19b05529', '936de313', '3aa6f4e2', 'b1426003', 'c5e3817f', 'c099668c', 'ad63d93c', 'b487da60', '6940f7f3', '962f27eb', 'd9462202', '91d5933a', '1aed7c6d', '0ab3b47d', '28ef2a01', 'e54a0f16', '66cff190', '9190045a', '3bdf05d3', '8335f893', '29b81b73', '54d9ccb5', '1942abd7', 'a6d586b7', '364c0853', 'dca2797e', 'e6e29c47', 'f2dd248e', 'cab100c9', '6071a214', '0e17f595', 'eee9b9e2', 'da7689f1', '8b775397', 'e14a99a5', '1816b768', '6b81fead', 'aa753bb9', '1a9afd33', 'b7a6f709', 'fa7895de', 'dc2222d7', 'e95c70e2', '264f471d', '6d818f6c', 'd107dc42', '060cd039', 'bdb26021', '1657c9fa', '62641b88', 'a9f38bae', 'f34e6f44', 'bc196f81', 'e63b69c5', 'b17f5ba0', 'ab00c4b2', 'a8cf01bc', 'b41a92a3', '23ad12d8', '8a5acefd', 'db9d52d2', 'c013fe4d', '61bcb275', 'd874a786', 'b433332a', '171b56dc', '750e3e75', '2d056836', '10f2bb12', '1bc45db9', '471a0925', '989a2213', 'b00dff7e', 'ec21c46b', 'c90c0105', 'dbb40d24', '96c67073', '257e17e0', 'c2d15ea5', 'e8e960fd', '50ed8a7b', '2e0d80f7', '57cb3575', '3b853f44', 'c4cfbe43', 'f5e5e8b0', '56eb74ae', '9d32f10a', '7eee5973', 'ab7b5acd', '90804775', '538e1856', '6f5b4d3d', 'bca56796', '3ca784ec'}
# {'down', 'no', 'off', 'unknown', 'left', 'on', 'right', 'yes', 'up', 'go', 'silence', 'stop'}
# There are 57929 train and 6798 val samples

# %%
trainset
# Out:
# [(11, '00176480', '../data/train/audio/bed/00176480_nohash_0.wav'),
#  (11, '004ae714', '../data/train/audio/bed/004ae714_nohash_0.wav'),
#  (11, '004ae714', '../data/train/audio/bed/004ae714_nohash_1.wav'),
#  (11, '00f0204f', '../data/train/audio/bed/00f0204f_nohash_0.wav'),
#  (11, '00f0204f', '../data/train/audio/bed/00f0204f_nohash_1.wav'),
#  (11, '012c8314', '../data/train/audio/bed/012c8314_nohash_0.wav'),
#  (11, '012c8314', '../data/train/audio/bed/012c8314_nohash_1.wav'),
#  (11, '0132a06d', '../data/train/audio/bed/0132a06d_nohash_0.wav'),
#  (11, '0135f3f2', '../data/train/audio/bed/0135f3f2_nohash_0.wav'),
#  (11, '0137b3f4', '../data/train/audio/bed/0137b3f4_nohash_0.wav'),
#  (11, '014f9f65', '../data/train/audio/bed/014f9f65_nohash_0.wav'),
#  (11, '01648c51', '../data/train/audio/bed/01648c51_nohash_0.wav'),
#  (11, '01648c51', '../data/train/audio/bed/01648c51_nohash_1.wav'),
#  (11, '016e2c6d', '../data/train/audio/bed/016e2c6d_nohash_0.wav'),
#  (11, '01b4757a', '../data/train/audio/bed/01b4757a_nohash_0.wav'),
#  (11, '01b4757a', '../data/train/audio/bed/01b4757a_nohash_1.wav'),
#  (11, '01bcfc0c', '../data/train/audio/bed/01bcfc0c_nohash_0.wav'),
#  (11, '0227998e', '../data/train/audio/bed/0227998e_nohash_0.wav'),
#  (11, '02746d24', '../data/train/audio/bed/02746d24_nohash_0.wav'),
#  (11, '035de8fe', '../data/train/audio/bed/035de8fe_nohash_0.wav'),
#  (11, '0362539c', '../data/train/audio/bed/0362539c_nohash_0.wav'),
#  (11, '0362539c', '../data/train/audio/bed/0362539c_nohash_1.wav'),
#  (11, '037c445a', '../data/train/audio/bed/037c445a_nohash_0.wav'),
#  (11, '0397ecda', '../data/train/audio/bed/0397ecda_nohash_0.wav'),
#  (11, '03c96658', '../data/train/audio/bed/03c96658_nohash_0.wav'),
#  (11, '042186b8', '../data/train/audio/bed/042186b8_nohash_0.wav'),
#  (11, '042ea76c', '../data/train/audio/bed/042ea76c_nohash_0.wav'),
#  (11, '0447d7c1', '../data/train/audio/bed/0447d7c1_nohash_0.wav'),
#  (11, '0474c92a', '../data/train/audio/bed/0474c92a_nohash_0.wav'),
#  (11, '0474c92a', '../data/train/audio/bed/0474c92a_nohash_1.wav'),
#  (11, '05739450', '../data/train/audio/bed/05739450_nohash_0.wav'),
#  (11, '05b2db80', '../data/train/audio/bed/05b2db80_nohash_0.wav'),
#  (11, '05d18852', '../data/train/audio/bed/05d18852_nohash_0.wav'),
#  (11, '06076b6b', '../data/train/audio/bed/06076b6b_nohash_0.wav'),
#  (11, '063d48cf', '../data/train/audio/bed/063d48cf_nohash_0.wav'),
#  (11, '063d48cf', '../data/train/audio/bed/063d48cf_nohash_1.wav'),
#  (11, '0685264e', '../data/train/audio/bed/0685264e_nohash_0.wav'),
#  (11, '07363607', '../data/train/audio/bed/07363607_nohash_0.wav'),
#  (11, '079dfce3', '../data/train/audio/bed/079dfce3_nohash_0.wav'),
#  (11, '079dfce3', '../data/train/audio/bed/079dfce3_nohash_1.wav'),
#  (11, '079dfce3', '../data/train/audio/bed/079dfce3_nohash_2.wav'),
#  (11, '07c5129e', '../data/train/audio/bed/07c5129e_nohash_0.wav'),
#  (11, '09bcdc9d', '../data/train/audio/bed/09bcdc9d_nohash_0.wav'),
#  (11, '09bcdc9d', '../data/train/audio/bed/09bcdc9d_nohash_1.wav'),
#  (11, '09ddc105', '../data/train/audio/bed/09ddc105_nohash_0.wav'),
#  (11, '09ddc105', '../data/train/audio/bed/09ddc105_nohash_1.wav'),
#  (11, '0a7c2a8d', '../data/train/audio/bed/0a7c2a8d_nohash_0.wav'),
#  (11, '0b09edd3', '../data/train/audio/bed/0b09edd3_nohash_0.wav'),
#  (11, '0b56bcfe', '../data/train/audio/bed/0b56bcfe_nohash_0.wav'),
#  (11, '0b77ee66', '../data/train/audio/bed/0b77ee66_nohash_0.wav'),
#  (11, '0b77ee66', '../data/train/audio/bed/0b77ee66_nohash_1.wav'),
#  (11, '0b77ee66', '../data/train/audio/bed/0b77ee66_nohash_2.wav'),
#  (11, '0bde966a', '../data/train/audio/bed/0bde966a_nohash_0.wav'),
#  (11, '0bde966a', '../data/train/audio/bed/0bde966a_nohash_1.wav'),
#  (11, '0c2ca723', '../data/train/audio/bed/0c2ca723_nohash_0.wav'),
#  (11, '0c2ca723', '../data/train/audio/bed/0c2ca723_nohash_1.wav'),
#  (11, '0c2d2ffa', '../data/train/audio/bed/0c2d2ffa_nohash_0.wav'),
#  (11, '0c2d2ffa', '../data/train/audio/bed/0c2d2ffa_nohash_1.wav'),
#  (11, '0c40e715', '../data/train/audio/bed/0c40e715_nohash_0.wav'),
#  (11, '0d2bcf9d', '../data/train/audio/bed/0d2bcf9d_nohash_0.wav'),
#  (11, '0d2bcf9d', '../data/train/audio/bed/0d2bcf9d_nohash_1.wav'),
#  (11, '0d393936', '../data/train/audio/bed/0d393936_nohash_0.wav'),
#  (11, '0e5193e6', '../data/train/audio/bed/0e5193e6_nohash_0.wav'),
#  (11, '0ea0e2f4', '../data/train/audio/bed/0ea0e2f4_nohash_0.wav'),
#  (11, '0ea0e2f4', '../data/train/audio/bed/0ea0e2f4_nohash_1.wav'),
#  (11, '0f7dc557', '../data/train/audio/bed/0f7dc557_nohash_0.wav'),
#  (11, '0ff728b5', '../data/train/audio/bed/0ff728b5_nohash_0.wav'),
#  (11, '102192fd', '../data/train/audio/bed/102192fd_nohash_0.wav'),
#  (11, '10467b06', '../data/train/audio/bed/10467b06_nohash_0.wav'),
#  (11, '105a0eea', '../data/train/audio/bed/105a0eea_nohash_0.wav'),
#  (11, '10627519', '../data/train/audio/bed/10627519_nohash_0.wav'),
#  (11, '106a6183', '../data/train/audio/bed/106a6183_nohash_0.wav'),
#  (11, '10ace7eb', '../data/train/audio/bed/10ace7eb_nohash_0.wav'),
#  (11, '10c6d873', '../data/train/audio/bed/10c6d873_nohash_0.wav'),
#  (11, '11321027', '../data/train/audio/bed/11321027_nohash_0.wav'),
#  (11, '118261a9', '../data/train/audio/bed/118261a9_nohash_0.wav'),
#  (11, '118261a9', '../data/train/audio/bed/118261a9_nohash_1.wav'),
#  (11, '118261a9', '../data/train/audio/bed/118261a9_nohash_2.wav'),
#  (11, '11860c84', '../data/train/audio/bed/11860c84_nohash_0.wav'),
#  (11, '11a022ba', '../data/train/audio/bed/11a022ba_nohash_0.wav'),
#  (11, '11b1df78', '../data/train/audio/bed/11b1df78_nohash_0.wav'),
#  (11, '11b1df78', '../data/train/audio/bed/11b1df78_nohash_1.wav'),
#  (11, '122c5aa7', '../data/train/audio/bed/122c5aa7_nohash_0.wav'),
#  (11, '12529547', '../data/train/audio/bed/12529547_nohash_0.wav'),
#  (11, '126a31d2', '../data/train/audio/bed/126a31d2_nohash_0.wav'),
#  (11, '129c7d8d', '../data/train/audio/bed/129c7d8d_nohash_0.wav'),
#  (11, '13199b79', '../data/train/audio/bed/13199b79_nohash_0.wav'),
#  (11, '1365dd89', '../data/train/audio/bed/1365dd89_nohash_0.wav'),
#  (11, '1365dd89', '../data/train/audio/bed/1365dd89_nohash_1.wav'),
#  (11, '146d97db', '../data/train/audio/bed/146d97db_nohash_0.wav'),
#  (11, '14872d06', '../data/train/audio/bed/14872d06_nohash_0.wav'),
#  (11, '14872d06', '../data/train/audio/bed/14872d06_nohash_1.wav'),
#  (11, '14df1e28', '../data/train/audio/bed/14df1e28_nohash_0.wav'),
#  (11, '1528225c', '../data/train/audio/bed/1528225c_nohash_0.wav'),
#  (11, '1528225c', '../data/train/audio/bed/1528225c_nohash_1.wav'),
#  (11, '1528225c', '../data/train/audio/bed/1528225c_nohash_2.wav'),
#  (11, '1528225c', '../data/train/audio/bed/1528225c_nohash_3.wav'),
#  (11, '15b0c947', '../data/train/audio/bed/15b0c947_nohash_0.wav'),
#  (11, '15c371c7', '../data/train/audio/bed/15c371c7_nohash_0.wav'),
#  (11, '15c563d7', '../data/train/audio/bed/15c563d7_nohash_0.wav'),
#  (11, '15d83b54', '../data/train/audio/bed/15d83b54_nohash_0.wav'),
#  (11, '15d83b54', '../data/train/audio/bed/15d83b54_nohash_1.wav'),
#  (11, '15f04ff8', '../data/train/audio/bed/15f04ff8_nohash_0.wav'),
#  (11, '161fcca8', '../data/train/audio/bed/161fcca8_nohash_0.wav'),
#  (11, '161fcca8', '../data/train/audio/bed/161fcca8_nohash_1.wav'),
#  (11, '1625acd8', '../data/train/audio/bed/1625acd8_nohash_0.wav'),
#  (11, '1625acd8', '../data/train/audio/bed/1625acd8_nohash_1.wav'),
#  (11, '16d41d07', '../data/train/audio/bed/16d41d07_nohash_0.wav'),
#  (11, '1706c35f', '../data/train/audio/bed/1706c35f_nohash_0.wav'),
#  (11, '1706c35f', '../data/train/audio/bed/1706c35f_nohash_1.wav'),
#  (11, '1706c35f', '../data/train/audio/bed/1706c35f_nohash_2.wav'),
#  (11, '1706c35f', '../data/train/audio/bed/1706c35f_nohash_3.wav'),
#  (11, '172dc2b0', '../data/train/audio/bed/172dc2b0_nohash_0.wav'),
#  (11, '172dc2b0', '../data/train/audio/bed/172dc2b0_nohash_1.wav'),
#  (11, '172dc2b0', '../data/train/audio/bed/172dc2b0_nohash_2.wav'),
#  (11, '173ae793', '../data/train/audio/bed/173ae793_nohash_0.wav'),
#  (11, '173ae793', '../data/train/audio/bed/173ae793_nohash_1.wav'),
#  (11, '173ce2be', '../data/train/audio/bed/173ce2be_nohash_0.wav'),
#  (11, '173ce2be', '../data/train/audio/bed/173ce2be_nohash_1.wav'),
#  (11, '1746d7b6', '../data/train/audio/bed/1746d7b6_nohash_0.wav'),
#  (11, '179a61b7', '../data/train/audio/bed/179a61b7_nohash_0.wav'),
#  (11, '17c94b23', '../data/train/audio/bed/17c94b23_nohash_0.wav'),
#  (11, '17cc40ee', '../data/train/audio/bed/17cc40ee_nohash_0.wav'),
#  (11, '17f0e206', '../data/train/audio/bed/17f0e206_nohash_0.wav'),
#  (11, '17f0e206', '../data/train/audio/bed/17f0e206_nohash_1.wav'),
#  (11, '187af8be', '../data/train/audio/bed/187af8be_nohash_0.wav'),
#  (11, '1887fe04', '../data/train/audio/bed/1887fe04_nohash_0.wav'),
#  (11, '1890e5c3', '../data/train/audio/bed/1890e5c3_nohash_0.wav'),
#  (11, '18a1aab9', '../data/train/audio/bed/18a1aab9_nohash_0.wav'),
#  (11, '18a8f03f', '../data/train/audio/bed/18a8f03f_nohash_0.wav'),
#  (11, '18a8f03f', '../data/train/audio/bed/18a8f03f_nohash_1.wav'),
#  (11, '18a8f03f', '../data/train/audio/bed/18a8f03f_nohash_2.wav'),
#  (11, '18c54a68', '../data/train/audio/bed/18c54a68_nohash_0.wav'),
#  (11, '18c54a68', '../data/train/audio/bed/18c54a68_nohash_1.wav'),
#  (11, '18c54a68', '../data/train/audio/bed/18c54a68_nohash_2.wav'),
#  (11, '18c54a68', '../data/train/audio/bed/18c54a68_nohash_3.wav'),
#  (11, '18c54a68', '../data/train/audio/bed/18c54a68_nohash_4.wav'),
#  (11, '190821dc', '../data/train/audio/bed/190821dc_nohash_0.wav'),
#  (11, '19785c4e', '../data/train/audio/bed/19785c4e_nohash_0.wav'),
#  (11, '19785c4e', '../data/train/audio/bed/19785c4e_nohash_1.wav'),
#  (11, '19785c4e', '../data/train/audio/bed/19785c4e_nohash_2.wav'),
#  (11, '1993db46', '../data/train/audio/bed/1993db46_nohash_0.wav'),
#  (11, '1995cf9e', '../data/train/audio/bed/1995cf9e_nohash_0.wav'),
#  (11, '19e246ad', '../data/train/audio/bed/19e246ad_nohash_0.wav'),
#  (11, '19f9c115', '../data/train/audio/bed/19f9c115_nohash_0.wav'),
#  (11, '19f9c115', '../data/train/audio/bed/19f9c115_nohash_1.wav'),
#  (11, '19f9c115', '../data/train/audio/bed/19f9c115_nohash_2.wav'),
#  (11, '19f9c115', '../data/train/audio/bed/19f9c115_nohash_3.wav'),
#  (11, '1a073312', '../data/train/audio/bed/1a073312_nohash_0.wav'),
#  (11, '1a073312', '../data/train/audio/bed/1a073312_nohash_1.wav'),
#  (11, '1a4259c3', '../data/train/audio/bed/1a4259c3_nohash_0.wav'),
#  (11, '1a4259c3', '../data/train/audio/bed/1a4259c3_nohash_1.wav'),
#  (11, '1a5b9ca4', '../data/train/audio/bed/1a5b9ca4_nohash_0.wav'),
#  (11, '1a5b9ca4', '../data/train/audio/bed/1a5b9ca4_nohash_1.wav'),
#  (11, '1a673010', '../data/train/audio/bed/1a673010_nohash_0.wav'),
#  (11, '1a6eca98', '../data/train/audio/bed/1a6eca98_nohash_0.wav'),
#  (11, '1a6eca98', '../data/train/audio/bed/1a6eca98_nohash_1.wav'),
#  (11, '1a892463', '../data/train/audio/bed/1a892463_nohash_0.wav'),
#  (11, '1afd49bf', '../data/train/audio/bed/1afd49bf_nohash_0.wav'),
#  (11, '1afd49bf', '../data/train/audio/bed/1afd49bf_nohash_1.wav'),
#  (11, '1b459024', '../data/train/audio/bed/1b459024_nohash_0.wav'),
#  (11, '1b4c9b89', '../data/train/audio/bed/1b4c9b89_nohash_0.wav'),
#  (11, '1b63157b', '../data/train/audio/bed/1b63157b_nohash_0.wav'),
#  (11, '1b755c65', '../data/train/audio/bed/1b755c65_nohash_0.wav'),
#  (11, '1b755c65', '../data/train/audio/bed/1b755c65_nohash_1.wav'),
#  (11, '1bb574f9', '../data/train/audio/bed/1bb574f9_nohash_0.wav'),
#  (11, '1bb6ed89', '../data/train/audio/bed/1bb6ed89_nohash_0.wav'),
#  (11, '1bb6ed89', '../data/train/audio/bed/1bb6ed89_nohash_1.wav'),
#  (11, '1c3f50ad', '../data/train/audio/bed/1c3f50ad_nohash_0.wav'),
#  (11, '1c45ceb2', '../data/train/audio/bed/1c45ceb2_nohash_0.wav'),
#  (11, '1c6e5447', '../data/train/audio/bed/1c6e5447_nohash_0.wav'),
#  (11, '1cb788bc', '../data/train/audio/bed/1cb788bc_nohash_0.wav'),
#  (11, '1cb788bc', '../data/train/audio/bed/1cb788bc_nohash_1.wav'),
#  (11, '1cbcc7a7', '../data/train/audio/bed/1cbcc7a7_nohash_0.wav'),
#  (11, '1d1fe0a0', '../data/train/audio/bed/1d1fe0a0_nohash_0.wav'),
#  (11, '1dce06e8', '../data/train/audio/bed/1dce06e8_nohash_0.wav'),
#  (11, '1df483c0', '../data/train/audio/bed/1df483c0_nohash_0.wav'),
#  (11, '1df99a8a', '../data/train/audio/bed/1df99a8a_nohash_0.wav'),
#  (11, '1df99a8a', '../data/train/audio/bed/1df99a8a_nohash_1.wav'),
#  (11, '1e4064b8', '../data/train/audio/bed/1e4064b8_nohash_0.wav'),
#  (11, '1e4064b8', '../data/train/audio/bed/1e4064b8_nohash_1.wav'),
#  (11, '1e412fac', '../data/train/audio/bed/1e412fac_nohash_0.wav'),
#  (11, '1ecfb537', '../data/train/audio/bed/1ecfb537_nohash_0.wav'),
#  (11, '1ed557b9', '../data/train/audio/bed/1ed557b9_nohash_0.wav'),
#  (11, '1ffd513b', '../data/train/audio/bed/1ffd513b_nohash_0.wav'),
#  (11, '20174140', '../data/train/audio/bed/20174140_nohash_0.wav'),
#  (11, '2039b9c1', '../data/train/audio/bed/2039b9c1_nohash_0.wav'),
#  (11, '20d3f11f', '../data/train/audio/bed/20d3f11f_nohash_0.wav'),
#  (11, '210f3aa9', '../data/train/audio/bed/210f3aa9_nohash_0.wav'),
#  (11, '21307344', '../data/train/audio/bed/21307344_nohash_0.wav'),
#  (11, '215699ff', '../data/train/audio/bed/215699ff_nohash_0.wav'),
#  (11, '215699ff', '../data/train/audio/bed/215699ff_nohash_1.wav'),
#  (11, '21832144', '../data/train/audio/bed/21832144_nohash_0.wav'),
#  (11, '21cbe292', '../data/train/audio/bed/21cbe292_nohash_0.wav'),
#  (11, '21e8c417', '../data/train/audio/bed/21e8c417_nohash_0.wav'),
#  (11, '229978fd', '../data/train/audio/bed/229978fd_nohash_0.wav'),
#  (11, '2313e093', '../data/train/audio/bed/2313e093_nohash_0.wav'),
#  (11, '234ab0fb', '../data/train/audio/bed/234ab0fb_nohash_0.wav'),
#  (11, '238c112c', '../data/train/audio/bed/238c112c_nohash_0.wav'),
#  (11, '23abe1c9', '../data/train/audio/bed/23abe1c9_nohash_0.wav'),
#  (11, '24b82192', '../data/train/audio/bed/24b82192_nohash_0.wav'),
#  (11, '24befdb3', '../data/train/audio/bed/24befdb3_nohash_0.wav'),
#  (11, '24ed94ab', '../data/train/audio/bed/24ed94ab_nohash_0.wav'),
#  (11, '24ed94ab', '../data/train/audio/bed/24ed94ab_nohash_1.wav'),
#  (11, '25040e85', '../data/train/audio/bed/25040e85_nohash_0.wav'),
#  (11, '2510c044', '../data/train/audio/bed/2510c044_nohash_0.wav'),
#  (11, '25132942', '../data/train/audio/bed/25132942_nohash_0.wav'),
#  (11, '2589f361', '../data/train/audio/bed/2589f361_nohash_0.wav'),
#  (11, '25c14394', '../data/train/audio/bed/25c14394_nohash_0.wav'),
#  (11, '25c14394', '../data/train/audio/bed/25c14394_nohash_1.wav'),
#  (11, '26e573a9', '../data/train/audio/bed/26e573a9_nohash_0.wav'),
#  (11, '26e9ae6b', '../data/train/audio/bed/26e9ae6b_nohash_0.wav'),
#  (11, '26e9ae6b', '../data/train/audio/bed/26e9ae6b_nohash_1.wav'),
#  (11, '26e9ae6b', '../data/train/audio/bed/26e9ae6b_nohash_2.wav'),
#  (11, '270bfa52', '../data/train/audio/bed/270bfa52_nohash_0.wav'),
#  (11, '274c008f', '../data/train/audio/bed/274c008f_nohash_0.wav'),
#  (11, '2796ac50', '../data/train/audio/bed/2796ac50_nohash_0.wav'),
#  (11, '27b03931', '../data/train/audio/bed/27b03931_nohash_0.wav'),
#  (11, '283d7a53', '../data/train/audio/bed/283d7a53_nohash_0.wav'),
#  (11, '28460a60', '../data/train/audio/bed/28460a60_nohash_0.wav'),
#  (11, '28497c5b', '../data/train/audio/bed/28497c5b_nohash_0.wav'),
#  (11, '28612180', '../data/train/audio/bed/28612180_nohash_0.wav'),
#  (11, '28612180', '../data/train/audio/bed/28612180_nohash_1.wav'),
#  (11, '28612180', '../data/train/audio/bed/28612180_nohash_2.wav'),
#  (11, '28ce0c58', '../data/train/audio/bed/28ce0c58_nohash_0.wav'),
#  (11, '28e47b1a', '../data/train/audio/bed/28e47b1a_nohash_0.wav'),
#  (11, '28ed6bc9', '../data/train/audio/bed/28ed6bc9_nohash_0.wav'),
#  (11, '29fb33da', '../data/train/audio/bed/29fb33da_nohash_0.wav'),
#  (11, '2a0b413e', '../data/train/audio/bed/2a0b413e_nohash_0.wav'),
#  (11, '2aec99ec', '../data/train/audio/bed/2aec99ec_nohash_0.wav'),
#  (11, '2aec99ec', '../data/train/audio/bed/2aec99ec_nohash_1.wav'),
#  (11, '2b3f509b', '../data/train/audio/bed/2b3f509b_nohash_0.wav'),
#  (11, '2bd2cad5', '../data/train/audio/bed/2bd2cad5_nohash_0.wav'),
#  (11, '2bd2cad5', '../data/train/audio/bed/2bd2cad5_nohash_1.wav'),
#  (11, '2bdbe5f7', '../data/train/audio/bed/2bdbe5f7_nohash_0.wav'),
#  (11, '2be08ce4', '../data/train/audio/bed/2be08ce4_nohash_0.wav'),
#  (11, '2be08ce4', '../data/train/audio/bed/2be08ce4_nohash_1.wav'),
#  (11, '2be08ce4', '../data/train/audio/bed/2be08ce4_nohash_2.wav'),
#  (11, '2bfe70ef', '../data/train/audio/bed/2bfe70ef_nohash_0.wav'),
#  (11, '2c6446f7', '../data/train/audio/bed/2c6446f7_nohash_0.wav'),
#  (11, '2c6d3924', '../data/train/audio/bed/2c6d3924_nohash_0.wav'),
#  (11, '2c7c33e8', '../data/train/audio/bed/2c7c33e8_nohash_0.wav'),
#  (11, '2cf28b70', '../data/train/audio/bed/2cf28b70_nohash_0.wav'),
#  (11, '2d82a556', '../data/train/audio/bed/2d82a556_nohash_0.wav'),
#  (11, '2d82a556', '../data/train/audio/bed/2d82a556_nohash_1.wav'),
#  (11, '2d92f18b', '../data/train/audio/bed/2d92f18b_nohash_0.wav'),
#  (11, '2d92f18b', '../data/train/audio/bed/2d92f18b_nohash_1.wav'),
#  (11, '2da58b32', '../data/train/audio/bed/2da58b32_nohash_0.wav'),
#  (11, '2dcb6848', '../data/train/audio/bed/2dcb6848_nohash_0.wav'),
#  (11, '2dcb6848', '../data/train/audio/bed/2dcb6848_nohash_1.wav'),
#  (11, '2f0a410b', '../data/train/audio/bed/2f0a410b_nohash_0.wav'),
#  (11, '300384f0', '../data/train/audio/bed/300384f0_nohash_0.wav'),
#  (11, '300384f0', '../data/train/audio/bed/300384f0_nohash_1.wav'),
#  (11, '30065f33', '../data/train/audio/bed/30065f33_nohash_0.wav'),
#  (11, '30065f33', '../data/train/audio/bed/30065f33_nohash_1.wav'),
#  (11, '30137d34', '../data/train/audio/bed/30137d34_nohash_0.wav'),
#  (11, '305776dd', '../data/train/audio/bed/305776dd_nohash_0.wav'),
#  (11, '305776dd', '../data/train/audio/bed/305776dd_nohash_1.wav'),
#  (11, '305776dd', '../data/train/audio/bed/305776dd_nohash_2.wav'),
#  (11, '30802c5d', '../data/train/audio/bed/30802c5d_nohash_0.wav'),
#  (11, '30a09789', '../data/train/audio/bed/30a09789_nohash_0.wav'),
#  (11, '30f31e42', '../data/train/audio/bed/30f31e42_nohash_0.wav'),
#  (11, '311fde72', '../data/train/audio/bed/311fde72_nohash_0.wav'),
#  (11, '31270cb2', '../data/train/audio/bed/31270cb2_nohash_0.wav'),
#  (11, '31270cb2', '../data/train/audio/bed/31270cb2_nohash_1.wav'),
#  (11, '3143fdff', '../data/train/audio/bed/3143fdff_nohash_0.wav'),
#  (11, '31583d30', '../data/train/audio/bed/31583d30_nohash_0.wav'),
#  (11, '31583d30', '../data/train/audio/bed/31583d30_nohash_1.wav'),
#  (11, '31583d30', '../data/train/audio/bed/31583d30_nohash_2.wav'),
#  (11, '31d31fa0', '../data/train/audio/bed/31d31fa0_nohash_0.wav'),
#  (11, '31d68957', '../data/train/audio/bed/31d68957_nohash_0.wav'),
#  (11, '3209ec42', '../data/train/audio/bed/3209ec42_nohash_0.wav'),
#  (11, '3209ec42', '../data/train/audio/bed/3209ec42_nohash_1.wav'),
#  (11, '324210dd', '../data/train/audio/bed/324210dd_nohash_0.wav'),
#  (11, '325a0c39', '../data/train/audio/bed/325a0c39_nohash_0.wav'),
#  (11, '32efce64', '../data/train/audio/bed/32efce64_nohash_0.wav'),
#  (11, '32efce64', '../data/train/audio/bed/32efce64_nohash_1.wav'),
#  (11, '32efce64', '../data/train/audio/bed/32efce64_nohash_2.wav'),
#  (11, '333784b7', '../data/train/audio/bed/333784b7_nohash_0.wav'),
#  (11, '3389305e', '../data/train/audio/bed/3389305e_nohash_0.wav'),
#  (11, '338dacf5', '../data/train/audio/bed/338dacf5_nohash_0.wav'),
#  (11, '33903159', '../data/train/audio/bed/33903159_nohash_0.wav'),
#  (11, '33f60c62', '../data/train/audio/bed/33f60c62_nohash_0.wav'),
#  (11, '3402e488', '../data/train/audio/bed/3402e488_nohash_0.wav'),
#  (11, '3411cf4b', '../data/train/audio/bed/3411cf4b_nohash_0.wav'),
#  (11, '3411cf4b', '../data/train/audio/bed/3411cf4b_nohash_1.wav'),
#  (11, '34263ab3', '../data/train/audio/bed/34263ab3_nohash_0.wav'),
#  (11, '34263ab3', '../data/train/audio/bed/34263ab3_nohash_1.wav'),
#  (11, '34263ab3', '../data/train/audio/bed/34263ab3_nohash_2.wav'),
#  (11, '34ba417a', '../data/train/audio/bed/34ba417a_nohash_0.wav'),
#  (11, '34ba417a', '../data/train/audio/bed/34ba417a_nohash_1.wav'),
#  (11, '34ba417a', '../data/train/audio/bed/34ba417a_nohash_2.wav'),
#  (11, '34e8c726', '../data/train/audio/bed/34e8c726_nohash_0.wav'),
#  (11, '34e8c726', '../data/train/audio/bed/34e8c726_nohash_1.wav'),
#  (11, '353b4d33', '../data/train/audio/bed/353b4d33_nohash_0.wav'),
#  (11, '3565ca83', '../data/train/audio/bed/3565ca83_nohash_0.wav'),
#  (11, '35c8fa78', '../data/train/audio/bed/35c8fa78_nohash_0.wav'),
#  (11, '35c8fa78', '../data/train/audio/bed/35c8fa78_nohash_1.wav'),
#  (11, '35d1b6ee', '../data/train/audio/bed/35d1b6ee_nohash_0.wav'),
#  (11, '36050ef3', '../data/train/audio/bed/36050ef3_nohash_0.wav'),
#  (11, '365531e2', '../data/train/audio/bed/365531e2_nohash_0.wav'),
#  (11, '36746d7f', '../data/train/audio/bed/36746d7f_nohash_0.wav'),
#  (11, '36746d7f', '../data/train/audio/bed/36746d7f_nohash_1.wav'),
#  (11, '370844f7', '../data/train/audio/bed/370844f7_nohash_0.wav'),
#  (11, '37b03ab1', '../data/train/audio/bed/37b03ab1_nohash_0.wav'),
#  (11, '37b03ab1', '../data/train/audio/bed/37b03ab1_nohash_1.wav'),
#  (11, '37dca74f', '../data/train/audio/bed/37dca74f_nohash_0.wav'),
#  (11, '37e8db82', '../data/train/audio/bed/37e8db82_nohash_0.wav'),
#  (11, '38d78313', '../data/train/audio/bed/38d78313_nohash_0.wav'),
#  (11, '39a12648', '../data/train/audio/bed/39a12648_nohash_0.wav'),
#  (11, '39a6b995', '../data/train/audio/bed/39a6b995_nohash_0.wav'),
#  (11, '39c13eed', '../data/train/audio/bed/39c13eed_nohash_0.wav'),
#  (11, '39dce8cc', '../data/train/audio/bed/39dce8cc_nohash_0.wav'),
#  (11, '39ec87ac', '../data/train/audio/bed/39ec87ac_nohash_0.wav'),
#  (11, '3a182c98', '../data/train/audio/bed/3a182c98_nohash_0.wav'),
#  (11, '3a33d3a4', '../data/train/audio/bed/3a33d3a4_nohash_0.wav'),
#  (11, '3a789a0d', '../data/train/audio/bed/3a789a0d_nohash_0.wav'),
#  (11, '3a7d8872', '../data/train/audio/bed/3a7d8872_nohash_0.wav'),
#  (11, '3ab9ba07', '../data/train/audio/bed/3ab9ba07_nohash_0.wav'),
#  (11, '3ac2e76f', '../data/train/audio/bed/3ac2e76f_nohash_0.wav'),
#  (11, '3b852f6f', '../data/train/audio/bed/3b852f6f_nohash_0.wav'),
#  (11, '3b852f6f', '../data/train/audio/bed/3b852f6f_nohash_1.wav'),
#  (11, '3bc21161', '../data/train/audio/bed/3bc21161_nohash_0.wav'),
#  (11, '3bfd30e6', '../data/train/audio/bed/3bfd30e6_nohash_0.wav'),
#  (11, '3c257192', '../data/train/audio/bed/3c257192_nohash_0.wav'),
#  (11, '3c6d55b3', '../data/train/audio/bed/3c6d55b3_nohash_0.wav'),
#  (11, '3c8dc702', '../data/train/audio/bed/3c8dc702_nohash_0.wav'),
#  (11, '3cdecb0b', '../data/train/audio/bed/3cdecb0b_nohash_0.wav'),
#  (11, '3cdecb0b', '../data/train/audio/bed/3cdecb0b_nohash_1.wav'),
#  (11, '3cfc6b3a', '../data/train/audio/bed/3cfc6b3a_nohash_0.wav'),
#  (11, '3d53244b', '../data/train/audio/bed/3d53244b_nohash_0.wav'),
#  (11, '3d6bee47', '../data/train/audio/bed/3d6bee47_nohash_0.wav'),
#  (11, '3da7f617', '../data/train/audio/bed/3da7f617_nohash_0.wav'),
#  (11, '3df9a3d4', '../data/train/audio/bed/3df9a3d4_nohash_0.wav'),
#  (11, '3df9a3d4', '../data/train/audio/bed/3df9a3d4_nohash_1.wav'),
#  (11, '3e31dffe', '../data/train/audio/bed/3e31dffe_nohash_0.wav'),
#  (11, '3e3b65eb', '../data/train/audio/bed/3e3b65eb_nohash_0.wav'),
#  (11, '3e3b65eb', '../data/train/audio/bed/3e3b65eb_nohash_1.wav'),
#  (11, '3e3fa7fd', '../data/train/audio/bed/3e3fa7fd_nohash_0.wav'),
#  (11, '3eb8764c', '../data/train/audio/bed/3eb8764c_nohash_0.wav'),
#  (11, '3eb8764c', '../data/train/audio/bed/3eb8764c_nohash_1.wav'),
#  (11, '3ec05c3d', '../data/train/audio/bed/3ec05c3d_nohash_0.wav'),
#  (11, '3ed3e49a', '../data/train/audio/bed/3ed3e49a_nohash_0.wav'),
#  (11, '3ed3e49a', '../data/train/audio/bed/3ed3e49a_nohash_1.wav'),
#  (11, '3ed3e49a', '../data/train/audio/bed/3ed3e49a_nohash_2.wav'),
#  (11, '3ed3e49a', '../data/train/audio/bed/3ed3e49a_nohash_3.wav'),
#  (11, '3efa7ec4', '../data/train/audio/bed/3efa7ec4_nohash_0.wav'),
#  (11, '3efa7ec4', '../data/train/audio/bed/3efa7ec4_nohash_1.wav'),
#  (11, '3efa7ec4', '../data/train/audio/bed/3efa7ec4_nohash_2.wav'),
#  (11, '3f170018', '../data/train/audio/bed/3f170018_nohash_0.wav'),
#  (11, '3f2b358d', '../data/train/audio/bed/3f2b358d_nohash_0.wav'),
#  (11, '3f339c33', '../data/train/audio/bed/3f339c33_nohash_0.wav'),
#  (11, '3fb8c268', '../data/train/audio/bed/3fb8c268_nohash_0.wav'),
#  (11, '3fdafe25', '../data/train/audio/bed/3fdafe25_nohash_0.wav'),
#  (11, '3ff840aa', '../data/train/audio/bed/3ff840aa_nohash_0.wav'),
#  (11, '3ff840aa', '../data/train/audio/bed/3ff840aa_nohash_1.wav'),
#  (11, '40115b19', '../data/train/audio/bed/40115b19_nohash_0.wav'),
#  (11, '402e2977', '../data/train/audio/bed/402e2977_nohash_0.wav'),
#  (11, '402e2977', '../data/train/audio/bed/402e2977_nohash_1.wav'),
#  (11, '413997c1', '../data/train/audio/bed/413997c1_nohash_0.wav'),
#  (11, '413bcfe1', '../data/train/audio/bed/413bcfe1_nohash_0.wav'),
#  (11, '41474817', '../data/train/audio/bed/41474817_nohash_0.wav'),
#  (11, '41777abb', '../data/train/audio/bed/41777abb_nohash_0.wav'),
#  (11, '418e7158', '../data/train/audio/bed/418e7158_nohash_0.wav'),
#  (11, '41dce6f5', '../data/train/audio/bed/41dce6f5_nohash_0.wav'),
#  (11, '422d3197', '../data/train/audio/bed/422d3197_nohash_0.wav'),
#  (11, '4290ca61', '../data/train/audio/bed/4290ca61_nohash_0.wav'),
#  (11, '42c6fff1', '../data/train/audio/bed/42c6fff1_nohash_0.wav'),
#  (11, '42c6fff1', '../data/train/audio/bed/42c6fff1_nohash_1.wav'),
#  (11, '42c6fff1', '../data/train/audio/bed/42c6fff1_nohash_2.wav'),
#  (11, '42ccb57a', '../data/train/audio/bed/42ccb57a_nohash_0.wav'),
#  (11, '42e3f068', '../data/train/audio/bed/42e3f068_nohash_0.wav'),
#  (11, '42e3f068', '../data/train/audio/bed/42e3f068_nohash_1.wav'),
#  (11, '435f9f9e', '../data/train/audio/bed/435f9f9e_nohash_0.wav'),
#  (11, '43691f67', '../data/train/audio/bed/43691f67_nohash_0.wav'),
#  (11, '43b85b64', '../data/train/audio/bed/43b85b64_nohash_0.wav'),
#  (11, '43b85b64', '../data/train/audio/bed/43b85b64_nohash_1.wav'),
#  (11, '43f57297', '../data/train/audio/bed/43f57297_nohash_0.wav'),
#  (11, '43f57297', '../data/train/audio/bed/43f57297_nohash_1.wav'),
#  (11, '43fc47a7', '../data/train/audio/bed/43fc47a7_nohash_0.wav'),
#  (11, '4407ba92', '../data/train/audio/bed/4407ba92_nohash_0.wav'),
#  (11, '4407ba92', '../data/train/audio/bed/4407ba92_nohash_1.wav'),
#  (11, '44260689', '../data/train/audio/bed/44260689_nohash_0.wav'),
#  (11, '44b5720d', '../data/train/audio/bed/44b5720d_nohash_0.wav'),
#  (11, '44b5720d', '../data/train/audio/bed/44b5720d_nohash_1.wav'),
#  (11, '44b5720d', '../data/train/audio/bed/44b5720d_nohash_2.wav'),
#  (11, '460f2bad', '../data/train/audio/bed/460f2bad_nohash_0.wav'),
#  (11, '46114b4e', '../data/train/audio/bed/46114b4e_nohash_0.wav'),
#  (11, '46114b4e', '../data/train/audio/bed/46114b4e_nohash_1.wav'),
#  (11, '46114b4e', '../data/train/audio/bed/46114b4e_nohash_2.wav'),
#  (11, '4620dc14', '../data/train/audio/bed/4620dc14_nohash_0.wav'),
#  (11, '462e1919', '../data/train/audio/bed/462e1919_nohash_0.wav'),
#  (11, '462e1919', '../data/train/audio/bed/462e1919_nohash_1.wav'),
#  (11, '46a153d8', '../data/train/audio/bed/46a153d8_nohash_0.wav'),
#  (11, '47565088', '../data/train/audio/bed/47565088_nohash_0.wav'),
#  (11, '47565088', '../data/train/audio/bed/47565088_nohash_1.wav'),
#  (11, '47565088', '../data/train/audio/bed/47565088_nohash_2.wav'),
#  (11, '479e64cc', '../data/train/audio/bed/479e64cc_nohash_0.wav'),
#  (11, '479e64cc', '../data/train/audio/bed/479e64cc_nohash_1.wav'),
#  (11, '47d01978', '../data/train/audio/bed/47d01978_nohash_0.wav'),
#  (11, '4845bb10', '../data/train/audio/bed/4845bb10_nohash_0.wav'),
#  (11, '48463cbc', '../data/train/audio/bed/48463cbc_nohash_0.wav'),
#  (11, '48463cbc', '../data/train/audio/bed/48463cbc_nohash_1.wav'),
#  (11, '48463cbc', '../data/train/audio/bed/48463cbc_nohash_2.wav'),
#  (11, '48a9f771', '../data/train/audio/bed/48a9f771_nohash_0.wav'),
#  (11, '48a9f771', '../data/train/audio/bed/48a9f771_nohash_1.wav'),
#  (11, '48bdc11c', '../data/train/audio/bed/48bdc11c_nohash_0.wav'),
#  (11, '48e8b82a', '../data/train/audio/bed/48e8b82a_nohash_0.wav'),
#  (11, '493392c6', '../data/train/audio/bed/493392c6_nohash_0.wav'),
#  (11, '493392c6', '../data/train/audio/bed/493392c6_nohash_1.wav'),
#  (11, '49af4432', '../data/train/audio/bed/49af4432_nohash_0.wav'),
#  (11, '4a1e736b', '../data/train/audio/bed/4a1e736b_nohash_0.wav'),
#  (11, '4a294341', '../data/train/audio/bed/4a294341_nohash_0.wav'),
#  (11, '4a803e67', '../data/train/audio/bed/4a803e67_nohash_0.wav'),
#  (11, '4a803e67', '../data/train/audio/bed/4a803e67_nohash_1.wav'),
#  (11, '4abb2400', '../data/train/audio/bed/4abb2400_nohash_0.wav'),
#  (11, '4abb2400', '../data/train/audio/bed/4abb2400_nohash_1.wav'),
#  (11, '4b25f620', '../data/train/audio/bed/4b25f620_nohash_0.wav'),
#  (11, '4b25f620', '../data/train/audio/bed/4b25f620_nohash_1.wav'),
#  (11, '4bb1244f', '../data/train/audio/bed/4bb1244f_nohash_0.wav'),
#  (11, '4bb1244f', '../data/train/audio/bed/4bb1244f_nohash_1.wav'),
#  (11, '4beff0c5', '../data/train/audio/bed/4beff0c5_nohash_0.wav'),
#  (11, '4beff0c5', '../data/train/audio/bed/4beff0c5_nohash_1.wav'),
#  (11, '4beff0c5', '../data/train/audio/bed/4beff0c5_nohash_2.wav'),
#  (11, '4c13fe25', '../data/train/audio/bed/4c13fe25_nohash_0.wav'),
#  (11, '4c13fe25', '../data/train/audio/bed/4c13fe25_nohash_1.wav'),
#  (11, '4c13fe25', '../data/train/audio/bed/4c13fe25_nohash_2.wav'),
#  (11, '4c432947', '../data/train/audio/bed/4c432947_nohash_0.wav'),
#  (11, '4c432947', '../data/train/audio/bed/4c432947_nohash_1.wav'),
#  (11, '4c432947', '../data/train/audio/bed/4c432947_nohash_2.wav'),
#  (11, '4c4d2526', '../data/train/audio/bed/4c4d2526_nohash_0.wav'),
#  (11, '4c7c95de', '../data/train/audio/bed/4c7c95de_nohash_0.wav'),
#  (11, '4c7c95de', '../data/train/audio/bed/4c7c95de_nohash_1.wav'),
#  (11, '4c841771', '../data/train/audio/bed/4c841771_nohash_0.wav'),
#  (11, '4ca37738', '../data/train/audio/bed/4ca37738_nohash_0.wav'),
#  (11, '4ca37738', '../data/train/audio/bed/4ca37738_nohash_1.wav'),
#  (11, '4cb874bb', '../data/train/audio/bed/4cb874bb_nohash_0.wav'),
#  (11, '4d9e07cf', '../data/train/audio/bed/4d9e07cf_nohash_0.wav'),
#  (11, '4def68db', '../data/train/audio/bed/4def68db_nohash_0.wav'),
#  (11, '4def68db', '../data/train/audio/bed/4def68db_nohash_1.wav'),
#  (11, '4f086393', '../data/train/audio/bed/4f086393_nohash_0.wav'),
#  (11, '4f086393', '../data/train/audio/bed/4f086393_nohash_1.wav'),
#  (11, '4f256313', '../data/train/audio/bed/4f256313_nohash_0.wav'),
#  (11, '4f2ab70c', '../data/train/audio/bed/4f2ab70c_nohash_0.wav'),
#  (11, '4f8ef132', '../data/train/audio/bed/4f8ef132_nohash_0.wav'),
#  (11, '50033893', '../data/train/audio/bed/50033893_nohash_0.wav'),
#  (11, '50033893', '../data/train/audio/bed/50033893_nohash_1.wav'),
#  (11, '50033893', '../data/train/audio/bed/50033893_nohash_2.wav'),
#  (11, '50a7d406', '../data/train/audio/bed/50a7d406_nohash_0.wav'),
#  (11, '50a8ef27', '../data/train/audio/bed/50a8ef27_nohash_0.wav'),
#  (11, '50d1c8e3', '../data/train/audio/bed/50d1c8e3_nohash_0.wav'),
#  (11, '51055bda', '../data/train/audio/bed/51055bda_nohash_0.wav'),
#  (11, '512dc91a', '../data/train/audio/bed/512dc91a_nohash_0.wav'),
#  (11, '512dc91a', '../data/train/audio/bed/512dc91a_nohash_1.wav'),
#  (11, '5165cf0a', '../data/train/audio/bed/5165cf0a_nohash_0.wav'),
#  (11, '518588b6', '../data/train/audio/bed/518588b6_nohash_0.wav'),
#  (11, '518588b6', '../data/train/audio/bed/518588b6_nohash_1.wav'),
#  (11, '518588b6', '../data/train/audio/bed/518588b6_nohash_2.wav'),
#  (11, '51995cea', '../data/train/audio/bed/51995cea_nohash_0.wav'),
#  (11, '520b2c17', '../data/train/audio/bed/520b2c17_nohash_0.wav'),
#  (11, '5236848b', '../data/train/audio/bed/5236848b_nohash_0.wav'),
#  (11, '529eda42', '../data/train/audio/bed/529eda42_nohash_0.wav'),
#  (11, '531a5b8a', '../data/train/audio/bed/531a5b8a_nohash_0.wav'),
#  (11, '531a5b8a', '../data/train/audio/bed/531a5b8a_nohash_1.wav'),
#  (11, '533c6564', '../data/train/audio/bed/533c6564_nohash_0.wav'),
#  (11, '53458368', '../data/train/audio/bed/53458368_nohash_0.wav'),
#  (11, '53fd1780', '../data/train/audio/bed/53fd1780_nohash_0.wav'),
#  (11, '541e4079', '../data/train/audio/bed/541e4079_nohash_0.wav'),
#  (11, '54412eae', '../data/train/audio/bed/54412eae_nohash_0.wav'),
#  (11, '551e42e8', '../data/train/audio/bed/551e42e8_nohash_0.wav'),
#  (11, '553f1a79', '../data/train/audio/bed/553f1a79_nohash_0.wav'),
#  (11, '55d3725a', '../data/train/audio/bed/55d3725a_nohash_0.wav'),
#  (11, '55d3725a', '../data/train/audio/bed/55d3725a_nohash_1.wav'),
#  (11, '563aa4e6', '../data/train/audio/bed/563aa4e6_nohash_0.wav'),
#  (11, '5677ec77', '../data/train/audio/bed/5677ec77_nohash_0.wav'),
#  (11, '5677ec77', '../data/train/audio/bed/5677ec77_nohash_1.wav'),
#  (11, '569455ff', '../data/train/audio/bed/569455ff_nohash_0.wav'),
#  (11, '56eab10e', '../data/train/audio/bed/56eab10e_nohash_0.wav'),
#  (11, '56eab10e', '../data/train/audio/bed/56eab10e_nohash_1.wav'),
#  (11, '56eab10e', '../data/train/audio/bed/56eab10e_nohash_2.wav'),
#  (11, '56eab10e', '../data/train/audio/bed/56eab10e_nohash_3.wav'),
#  (11, '5705a0f9', '../data/train/audio/bed/5705a0f9_nohash_0.wav'),
#  (11, '5705a0f9', '../data/train/audio/bed/5705a0f9_nohash_1.wav'),
#  (11, '57376a4c', '../data/train/audio/bed/57376a4c_nohash_0.wav'),
#  (11, '573cdb8a', '../data/train/audio/bed/573cdb8a_nohash_0.wav'),
#  (11, '5744b6a7', '../data/train/audio/bed/5744b6a7_nohash_0.wav'),
#  (11, '57b38f48', '../data/train/audio/bed/57b38f48_nohash_0.wav'),
#  (11, '57b38f48', '../data/train/audio/bed/57b38f48_nohash_1.wav'),
#  (11, '57b68383', '../data/train/audio/bed/57b68383_nohash_0.wav'),
#  (11, '5828dfa2', '../data/train/audio/bed/5828dfa2_nohash_0.wav'),
#  (11, '5828dfa2', '../data/train/audio/bed/5828dfa2_nohash_1.wav'),
#  (11, '587f3271', '../data/train/audio/bed/587f3271_nohash_0.wav'),
#  (11, '587f3271', '../data/train/audio/bed/587f3271_nohash_1.wav'),
#  (11, '587f3271', '../data/train/audio/bed/587f3271_nohash_2.wav'),
#  (11, '589bce2c', '../data/train/audio/bed/589bce2c_nohash_0.wav'),
#  (11, '58df33b5', '../data/train/audio/bed/58df33b5_nohash_0.wav'),
#  (11, '590750e8', '../data/train/audio/bed/590750e8_nohash_0.wav'),
#  (11, '590750e8', '../data/train/audio/bed/590750e8_nohash_1.wav'),
#  (11, '5a0bc987', '../data/train/audio/bed/5a0bc987_nohash_0.wav'),
#  (11, '5a3712c9', '../data/train/audio/bed/5a3712c9_nohash_0.wav'),
#  (11, '5a9f7324', '../data/train/audio/bed/5a9f7324_nohash_0.wav'),
#  (11, '5aac2efa', '../data/train/audio/bed/5aac2efa_nohash_0.wav'),
#  (11, '5af0ca83', '../data/train/audio/bed/5af0ca83_nohash_0.wav'),
#  (11, '5b09db89', '../data/train/audio/bed/5b09db89_nohash_0.wav'),
#  (11, '5b1db3ee', '../data/train/audio/bed/5b1db3ee_nohash_0.wav'),
#  (11, '5b1db3ee', '../data/train/audio/bed/5b1db3ee_nohash_1.wav'),
#  (11, '5b1db3ee', '../data/train/audio/bed/5b1db3ee_nohash_2.wav'),
#  (11, '5b1db3ee', '../data/train/audio/bed/5b1db3ee_nohash_3.wav'),
#  (11, '5b1db3ee', '../data/train/audio/bed/5b1db3ee_nohash_4.wav'),
#  (11, '5ba724a7', '../data/train/audio/bed/5ba724a7_nohash_0.wav'),
#  (11, '5ba724a7', '../data/train/audio/bed/5ba724a7_nohash_1.wav'),
#  (11, '5be23def', '../data/train/audio/bed/5be23def_nohash_0.wav'),
#  (11, '5c39594f', '../data/train/audio/bed/5c39594f_nohash_0.wav'),
#  (11, '5c8af87a', '../data/train/audio/bed/5c8af87a_nohash_0.wav'),
#  (11, '5d9bb361', '../data/train/audio/bed/5d9bb361_nohash_0.wav'),
#  (11, '5d9bb361', '../data/train/audio/bed/5d9bb361_nohash_1.wav'),
#  (11, '5de8f2f0', '../data/train/audio/bed/5de8f2f0_nohash_0.wav'),
#  (11, '5e033479', '../data/train/audio/bed/5e033479_nohash_0.wav'),
#  (11, '5e033479', '../data/train/audio/bed/5e033479_nohash_1.wav'),
#  (11, '5e1b34a6', '../data/train/audio/bed/5e1b34a6_nohash_0.wav'),
#  (11, '5e3dde6b', '../data/train/audio/bed/5e3dde6b_nohash_0.wav'),
#  (11, '5efb758c', '../data/train/audio/bed/5efb758c_nohash_0.wav'),
#  (11, '5f1b1051', '../data/train/audio/bed/5f1b1051_nohash_0.wav'),
#  (11, '5f47fdf9', '../data/train/audio/bed/5f47fdf9_nohash_0.wav'),
#  (11, '5f8e50a0', '../data/train/audio/bed/5f8e50a0_nohash_0.wav'),
#  (11, '5f8e50a0', '../data/train/audio/bed/5f8e50a0_nohash_1.wav'),
#  (11, '5fb88f4c', '../data/train/audio/bed/5fb88f4c_nohash_0.wav'),
#  (11, '5ff3f9a1', '../data/train/audio/bed/5ff3f9a1_nohash_0.wav'),
#  (11, '6021f08b', '../data/train/audio/bed/6021f08b_nohash_0.wav'),
#  (11, '6021f08b', '../data/train/audio/bed/6021f08b_nohash_1.wav'),
#  (11, '60472d26', '../data/train/audio/bed/60472d26_nohash_0.wav'),
#  (11, '60472d26', '../data/train/audio/bed/60472d26_nohash_1.wav'),
#  (11, '60472d26', '../data/train/audio/bed/60472d26_nohash_2.wav'),
#  (11, '6094340e', '../data/train/audio/bed/6094340e_nohash_0.wav'),
#  (11, '611d2b50', '../data/train/audio/bed/611d2b50_nohash_0.wav'),
#  (11, '6166ae21', '../data/train/audio/bed/6166ae21_nohash_0.wav'),
#  (11, '617de221', '../data/train/audio/bed/617de221_nohash_0.wav'),
#  (11, '61a9f72a', '../data/train/audio/bed/61a9f72a_nohash_0.wav'),
#  (11, '61d3e51e', '../data/train/audio/bed/61d3e51e_nohash_0.wav'),
#  (11, '61e50f62', '../data/train/audio/bed/61e50f62_nohash_0.wav'),
#  (11, '61e50f62', '../data/train/audio/bed/61e50f62_nohash_1.wav'),
#  (11, '6205088b', '../data/train/audio/bed/6205088b_nohash_0.wav'),
#  (11, '6205088b', '../data/train/audio/bed/6205088b_nohash_1.wav'),
#  (11, '6205088b', '../data/train/audio/bed/6205088b_nohash_2.wav'),
#  (11, '6205088b', '../data/train/audio/bed/6205088b_nohash_3.wav'),
#  (11, '620ff0fa', '../data/train/audio/bed/620ff0fa_nohash_0.wav'),
#  (11, '62581901', '../data/train/audio/bed/62581901_nohash_0.wav'),
#  (11, '62581901', '../data/train/audio/bed/62581901_nohash_1.wav'),
#  (11, '625fd898', '../data/train/audio/bed/625fd898_nohash_0.wav'),
#  (11, '62605293', '../data/train/audio/bed/62605293_nohash_0.wav'),
#  (11, '62605293', '../data/train/audio/bed/62605293_nohash_1.wav'),
#  (11, '627c0bec', '../data/train/audio/bed/627c0bec_nohash_0.wav'),
#  (11, '627c0bec', '../data/train/audio/bed/627c0bec_nohash_1.wav'),
#  (11, '62ef962d', '../data/train/audio/bed/62ef962d_nohash_0.wav'),
#  (11, '62ef962d', '../data/train/audio/bed/62ef962d_nohash_1.wav'),
#  (11, '62ff07ef', '../data/train/audio/bed/62ff07ef_nohash_0.wav'),
#  (11, '62ff07ef', '../data/train/audio/bed/62ff07ef_nohash_1.wav'),
#  (11, '6366f61a', '../data/train/audio/bed/6366f61a_nohash_0.wav'),
#  (11, '637c702a', '../data/train/audio/bed/637c702a_nohash_0.wav'),
#  (11, '638548d5', '../data/train/audio/bed/638548d5_nohash_0.wav'),
#  (11, '638548d5', '../data/train/audio/bed/638548d5_nohash_1.wav'),
#  (11, '63996b7c', '../data/train/audio/bed/63996b7c_nohash_0.wav'),
#  (11, '63996b7c', '../data/train/audio/bed/63996b7c_nohash_1.wav'),
#  (11, '6414258b', '../data/train/audio/bed/6414258b_nohash_0.wav'),
#  (11, '6414258b', '../data/train/audio/bed/6414258b_nohash_1.wav'),
#  (11, '64220627', '../data/train/audio/bed/64220627_nohash_0.wav'),
#  (11, '64220627', '../data/train/audio/bed/64220627_nohash_1.wav'),
#  (11, '64574a99', '../data/train/audio/bed/64574a99_nohash_0.wav'),
#  (11, '64da5281', '../data/train/audio/bed/64da5281_nohash_0.wav'),
#  (11, '64da5281', '../data/train/audio/bed/64da5281_nohash_1.wav'),
#  (11, '65040d9b', '../data/train/audio/bed/65040d9b_nohash_0.wav'),
#  (11, '650daf8e', '../data/train/audio/bed/650daf8e_nohash_0.wav'),
#  (11, '650daf8e', '../data/train/audio/bed/650daf8e_nohash_1.wav'),
#  (11, '650daf8e', '../data/train/audio/bed/650daf8e_nohash_2.wav'),
#  (11, '651d108f', '../data/train/audio/bed/651d108f_nohash_0.wav'),
#  (11, '652b3da7', '../data/train/audio/bed/652b3da7_nohash_0.wav'),
#  (11, '652b3da7', '../data/train/audio/bed/652b3da7_nohash_1.wav'),
#  (11, '652b3da7', '../data/train/audio/bed/652b3da7_nohash_2.wav'),
#  (11, '652b3da7', '../data/train/audio/bed/652b3da7_nohash_3.wav'),
#  (11, '653a48f5', '../data/train/audio/bed/653a48f5_nohash_0.wav'),
#  (11, '65c73b55', '../data/train/audio/bed/65c73b55_nohash_0.wav'),
#  (11, '65d81c54', '../data/train/audio/bed/65d81c54_nohash_0.wav'),
#  (11, '65d81c54', '../data/train/audio/bed/65d81c54_nohash_1.wav'),
#  (11, '65d844fc', '../data/train/audio/bed/65d844fc_nohash_0.wav'),
#  (11, '65f2531f', '../data/train/audio/bed/65f2531f_nohash_0.wav'),
#  (11, '66041c69', '../data/train/audio/bed/66041c69_nohash_0.wav'),
#  (11, '66041c69', '../data/train/audio/bed/66041c69_nohash_1.wav'),
#  (11, '66276b0e', '../data/train/audio/bed/66276b0e_nohash_0.wav'),
#  (11, '66276b0e', '../data/train/audio/bed/66276b0e_nohash_1.wav'),
#  (11, '66a412a7', '../data/train/audio/bed/66a412a7_nohash_0.wav'),
#  (11, '66aa0f29', '../data/train/audio/bed/66aa0f29_nohash_0.wav'),
#  (11, '6727b579', '../data/train/audio/bed/6727b579_nohash_0.wav'),
#  (11, '67961766', '../data/train/audio/bed/67961766_nohash_0.wav'),
#  (11, '67961766', '../data/train/audio/bed/67961766_nohash_1.wav'),
#  (11, '6823565f', '../data/train/audio/bed/6823565f_nohash_0.wav'),
#  (11, '682e1687', '../data/train/audio/bed/682e1687_nohash_0.wav'),
#  (11, '682e1687', '../data/train/audio/bed/682e1687_nohash_1.wav'),
#  (11, '6846af18', '../data/train/audio/bed/6846af18_nohash_0.wav'),
#  (11, '686d030b', '../data/train/audio/bed/686d030b_nohash_0.wav'),
#  (11, '6889b21f', '../data/train/audio/bed/6889b21f_nohash_0.wav'),
#  (11, '68dd409e', '../data/train/audio/bed/68dd409e_nohash_0.wav'),
#  (11, '68effe85', '../data/train/audio/bed/68effe85_nohash_0.wav'),
#  (11, '69086eb0', '../data/train/audio/bed/69086eb0_nohash_0.wav'),
#  (11, '692a88e6', '../data/train/audio/bed/692a88e6_nohash_0.wav'),
#  (11, '69953f48', '../data/train/audio/bed/69953f48_nohash_0.wav'),
#  (11, '6a014b29', '../data/train/audio/bed/6a014b29_nohash_0.wav'),
#  (11, '6a1908f8', '../data/train/audio/bed/6a1908f8_nohash_0.wav'),
#  (11, '6a203e0e', '../data/train/audio/bed/6a203e0e_nohash_0.wav'),
#  (11, '6a203e0e', '../data/train/audio/bed/6a203e0e_nohash_1.wav'),
#  (11, '6a2fb9a5', '../data/train/audio/bed/6a2fb9a5_nohash_0.wav'),
#  (11, '6a700f9d', '../data/train/audio/bed/6a700f9d_nohash_0.wav'),
#  (11, '6adb8ad9', '../data/train/audio/bed/6adb8ad9_nohash_0.wav'),
#  (11, '6af4aa07', '../data/train/audio/bed/6af4aa07_nohash_0.wav'),
#  (11, '6b7d5101', '../data/train/audio/bed/6b7d5101_nohash_0.wav'),
#  (11, '6b889021', '../data/train/audio/bed/6b889021_nohash_0.wav'),
#  (11, '6b889021', '../data/train/audio/bed/6b889021_nohash_1.wav'),
#  (11, '6b889021', '../data/train/audio/bed/6b889021_nohash_2.wav'),
#  (11, '6c429c7b', '../data/train/audio/bed/6c429c7b_nohash_0.wav'),
#  (11, '6c968bd9', '../data/train/audio/bed/6c968bd9_nohash_0.wav'),
#  (11, '6cc28ce5', '../data/train/audio/bed/6cc28ce5_nohash_0.wav'),
#  (11, '6ceeb9aa', '../data/train/audio/bed/6ceeb9aa_nohash_0.wav'),
#  (11, '6ceeb9aa', '../data/train/audio/bed/6ceeb9aa_nohash_1.wav'),
#  (11, '6d1dcca6', '../data/train/audio/bed/6d1dcca6_nohash_0.wav'),
#  (11, '6d1dcca6', '../data/train/audio/bed/6d1dcca6_nohash_1.wav'),
#  (11, '6d2d3b0d', '../data/train/audio/bed/6d2d3b0d_nohash_0.wav'),
#  (11, '6e2ef3d5', '../data/train/audio/bed/6e2ef3d5_nohash_0.wav'),
#  (11, '6e2ef3d5', '../data/train/audio/bed/6e2ef3d5_nohash_1.wav'),
#  (11, '6e41a77e', '../data/train/audio/bed/6e41a77e_nohash_0.wav'),
#  (11, '6e916de8', '../data/train/audio/bed/6e916de8_nohash_0.wav'),
#  (11, '6f2f57c1', '../data/train/audio/bed/6f2f57c1_nohash_0.wav'),
#  (11, '6f2f57c1', '../data/train/audio/bed/6f2f57c1_nohash_1.wav'),
#  (11, '6f342826', '../data/train/audio/bed/6f342826_nohash_0.wav'),
#  (11, '6f342826', '../data/train/audio/bed/6f342826_nohash_1.wav'),
#  (11, '6f342826', '../data/train/audio/bed/6f342826_nohash_2.wav'),
#  (11, '6f342826', '../data/train/audio/bed/6f342826_nohash_3.wav'),
#  (11, '6f3458b3', '../data/train/audio/bed/6f3458b3_nohash_0.wav'),
#  (11, '6f5eea74', '../data/train/audio/bed/6f5eea74_nohash_0.wav'),
#  (11, '6f7724f5', '../data/train/audio/bed/6f7724f5_nohash_0.wav'),
#  (11, '6f9088d7', '../data/train/audio/bed/6f9088d7_nohash_0.wav'),
#  (11, '6fca237d', '../data/train/audio/bed/6fca237d_nohash_0.wav'),
#  (11, '7081436f', '../data/train/audio/bed/7081436f_nohash_0.wav'),
#  (11, '7081436f', '../data/train/audio/bed/7081436f_nohash_1.wav'),
#  (11, '708a9569', '../data/train/audio/bed/708a9569_nohash_0.wav'),
#  (11, '708a9569', '../data/train/audio/bed/708a9569_nohash_1.wav'),
#  (11, '70a00e98', '../data/train/audio/bed/70a00e98_nohash_0.wav'),
#  (11, '712e4d58', '../data/train/audio/bed/712e4d58_nohash_0.wav'),
#  (11, '716757ce', '../data/train/audio/bed/716757ce_nohash_0.wav'),
#  (11, '716757ce', '../data/train/audio/bed/716757ce_nohash_1.wav'),
#  (11, '71904de3', '../data/train/audio/bed/71904de3_nohash_0.wav'),
#  (11, '7192fddc', '../data/train/audio/bed/7192fddc_nohash_0.wav'),
#  (11, '71f6fed7', '../data/train/audio/bed/71f6fed7_nohash_0.wav'),
#  (11, '7211390b', '../data/train/audio/bed/7211390b_nohash_0.wav'),
#  (11, '72320401', '../data/train/audio/bed/72320401_nohash_0.wav'),
#  (11, '723efc4c', '../data/train/audio/bed/723efc4c_nohash_0.wav'),
#  (11, '7257420c', '../data/train/audio/bed/7257420c_nohash_0.wav'),
#  (11, '7257420c', '../data/train/audio/bed/7257420c_nohash_1.wav'),
#  (11, '726382d6', '../data/train/audio/bed/726382d6_nohash_0.wav'),
#  (11, '72aa7259', '../data/train/audio/bed/72aa7259_nohash_0.wav'),
#  (11, '72ca6a6d', '../data/train/audio/bed/72ca6a6d_nohash_0.wav'),
#  (11, '7303215d', '../data/train/audio/bed/7303215d_nohash_0.wav'),
#  (11, '7303215d', '../data/train/audio/bed/7303215d_nohash_1.wav'),
#  (11, '73124b26', '../data/train/audio/bed/73124b26_nohash_0.wav'),
#  (11, '73124b26', '../data/train/audio/bed/73124b26_nohash_1.wav'),
#  (11, '735845ab', '../data/train/audio/bed/735845ab_nohash_0.wav'),
#  (11, '73dda36a', '../data/train/audio/bed/73dda36a_nohash_0.wav'),
#  (11, '73f0c1f7', '../data/train/audio/bed/73f0c1f7_nohash_0.wav'),
#  (11, '742d6431', '../data/train/audio/bed/742d6431_nohash_0.wav'),
#  (11, '747e69fd', '../data/train/audio/bed/747e69fd_nohash_0.wav'),
#  (11, '747e69fd', '../data/train/audio/bed/747e69fd_nohash_1.wav'),
#  (11, '74b73f88', '../data/train/audio/bed/74b73f88_nohash_0.wav'),
#  (11, '75915c90', '../data/train/audio/bed/75915c90_nohash_0.wav'),
#  (11, '75b631ff', '../data/train/audio/bed/75b631ff_nohash_0.wav'),
#  (11, '763188c4', '../data/train/audio/bed/763188c4_nohash_0.wav'),
#  (11, '765ffccb', '../data/train/audio/bed/765ffccb_nohash_0.wav'),
#  (11, '765ffccb', '../data/train/audio/bed/765ffccb_nohash_1.wav'),
#  (11, '76e53db9', '../data/train/audio/bed/76e53db9_nohash_0.wav'),
#  (11, '772db621', '../data/train/audio/bed/772db621_nohash_0.wav'),
#  (11, '772db621', '../data/train/audio/bed/772db621_nohash_1.wav'),
#  (11, '7799c9cd', '../data/train/audio/bed/7799c9cd_nohash_0.wav'),
#  (11, '7799c9cd', '../data/train/audio/bed/7799c9cd_nohash_1.wav'),
#  (11, '77def3ee', '../data/train/audio/bed/77def3ee_nohash_0.wav'),
#  (11, '77def3ee', '../data/train/audio/bed/77def3ee_nohash_1.wav'),
#  (11, '77f185d3', '../data/train/audio/bed/77f185d3_nohash_0.wav'),
#  (11, '77f185d3', '../data/train/audio/bed/77f185d3_nohash_1.wav'),
#  (11, '78030270', '../data/train/audio/bed/78030270_nohash_0.wav'),
#  (11, '78102205', '../data/train/audio/bed/78102205_nohash_0.wav'),
#  (11, '78102205', '../data/train/audio/bed/78102205_nohash_1.wav'),
#  (11, '782c1305', '../data/train/audio/bed/782c1305_nohash_0.wav'),
#  (11, '7846fd85', '../data/train/audio/bed/7846fd85_nohash_0.wav'),
#  (11, '784e281a', '../data/train/audio/bed/784e281a_nohash_0.wav'),
#  (11, '78622c2b', '../data/train/audio/bed/78622c2b_nohash_0.wav'),
#  (11, '78884794', '../data/train/audio/bed/78884794_nohash_0.wav'),
#  (11, '78884794', '../data/train/audio/bed/78884794_nohash_1.wav'),
#  (11, '78884794', '../data/train/audio/bed/78884794_nohash_2.wav'),
#  (11, '789e4ee7', '../data/train/audio/bed/789e4ee7_nohash_0.wav'),
#  (11, '7910d292', '../data/train/audio/bed/7910d292_nohash_0.wav'),
#  (11, '7a5530c9', '../data/train/audio/bed/7a5530c9_nohash_0.wav'),
#  (11, '7a5530c9', '../data/train/audio/bed/7a5530c9_nohash_1.wav'),
#  (11, '7add4c5f', '../data/train/audio/bed/7add4c5f_nohash_0.wav'),
#  (11, '7b2e879e', '../data/train/audio/bed/7b2e879e_nohash_0.wav'),
#  (11, '7b2e879e', '../data/train/audio/bed/7b2e879e_nohash_1.wav'),
#  (11, '7b301939', '../data/train/audio/bed/7b301939_nohash_0.wav'),
#  (11, '7bf801d1', '../data/train/audio/bed/7bf801d1_nohash_0.wav'),
#  (11, '7c75a504', '../data/train/audio/bed/7c75a504_nohash_0.wav'),
#  (11, '7c9b43f0', '../data/train/audio/bed/7c9b43f0_nohash_0.wav'),
# ...
#  (11, '850e2222', '../data/train/audio/bed/850e2222_nohash_1.wav'),
#  (11, '857366dd', '../data/train/audio/bed/857366dd_nohash_0.wav'),
#  (11, '857366dd', '../data/train/audio/bed/857366dd_nohash_1.wav'),
#  (11, '85b877b5', '../data/train/audio/bed/85b877b5_nohash_0.wav'),
#  (11, '863880b7', '../data/train/audio/bed/863880b7_nohash_0.wav'),
#  (11, '863880b7', '../data/train/audio/bed/863880b7_nohash_1.wav'),
#  (11, '86648261', '../data/train/audio/bed/86648261_nohash_0.wav'),
#  (11, '86648261', '../data/train/audio/bed/86648261_nohash_1.wav'),
#  (11, '86f12ac0', '../data/train/audio/bed/86f12ac0_nohash_0.wav'),
#  (11, '87014d40', '../data/train/audio/bed/87014d40_nohash_0.wav'),
#  (11, '876c84d6', '../data/train/audio/bed/876c84d6_nohash_0.wav'),
#  (11, '876c84d6', '../data/train/audio/bed/876c84d6_nohash_1.wav'),
#  (11, '8781f4c1', '../data/train/audio/bed/8781f4c1_nohash_0.wav'),
#  (11, '8781f4c1', '../data/train/audio/bed/8781f4c1_nohash_1.wav'),
#  (11, '87c62767', '../data/train/audio/bed/87c62767_nohash_0.wav'),
#  (11, '87eff300', '../data/train/audio/bed/87eff300_nohash_0.wav'),
#  (11, '88120683', '../data/train/audio/bed/88120683_nohash_0.wav'),
#  (11, '881583a6', '../data/train/audio/bed/881583a6_nohash_0.wav'),
#  (11, '8830e17f', '../data/train/audio/bed/8830e17f_nohash_0.wav'),
#  (11, '884ae8e1', '../data/train/audio/bed/884ae8e1_nohash_0.wav'),
#  (11, '888a0c49', '../data/train/audio/bed/888a0c49_nohash_0.wav'),
#  (11, '88a487ce', '../data/train/audio/bed/88a487ce_nohash_0.wav'),
#  (11, '88e90bc1', '../data/train/audio/bed/88e90bc1_nohash_0.wav'),
#  (11, '89d6d11e', '../data/train/audio/bed/89d6d11e_nohash_0.wav'),
#  (11, '89ed36ab', '../data/train/audio/bed/89ed36ab_nohash_0.wav'),
#  (11, '89f3ab7d', '../data/train/audio/bed/89f3ab7d_nohash_0.wav'),
#  (11, '89f3ab7d', '../data/train/audio/bed/89f3ab7d_nohash_1.wav'),
#  (11, '89f680f3', '../data/train/audio/bed/89f680f3_nohash_0.wav'),
#  (11, '89f680f3', '../data/train/audio/bed/89f680f3_nohash_1.wav'),
#  (11, '89f680f3', '../data/train/audio/bed/89f680f3_nohash_2.wav'),
#  (11, '8a0457c9', '../data/train/audio/bed/8a0457c9_nohash_0.wav'),
#  (11, '8a0457c9', '../data/train/audio/bed/8a0457c9_nohash_1.wav'),
#  (11, '8a28231e', '../data/train/audio/bed/8a28231e_nohash_0.wav'),
#  (11, '8a28231e', '../data/train/audio/bed/8a28231e_nohash_1.wav'),
#  (11, '8a744054', '../data/train/audio/bed/8a744054_nohash_0.wav'),
#  (11, '8aa35b0c', '../data/train/audio/bed/8aa35b0c_nohash_0.wav'),
#  (11, '8aa35b0c', '../data/train/audio/bed/8aa35b0c_nohash_1.wav'),
#  (11, '8b39e36f', '../data/train/audio/bed/8b39e36f_nohash_0.wav'),
#  (11, '8b39e36f', '../data/train/audio/bed/8b39e36f_nohash_1.wav'),
#  (11, '8bbd98d0', '../data/train/audio/bed/8bbd98d0_nohash_0.wav'),
#  (11, '8c3c4715', '../data/train/audio/bed/8c3c4715_nohash_0.wav'),
#  (11, '8c3c4715', '../data/train/audio/bed/8c3c4715_nohash_1.wav'),
#  (11, '8c4854bc', '../data/train/audio/bed/8c4854bc_nohash_0.wav'),
#  (11, '8c4854bc', '../data/train/audio/bed/8c4854bc_nohash_1.wav'),
#  (11, '8c4854bc', '../data/train/audio/bed/8c4854bc_nohash_2.wav'),
#  (11, '8c7c9168', '../data/train/audio/bed/8c7c9168_nohash_0.wav'),
#  (11, '8c7f81df', '../data/train/audio/bed/8c7f81df_nohash_0.wav'),
#  (11, '8c888bbb', '../data/train/audio/bed/8c888bbb_nohash_0.wav'),
#  (11, '8d5d076d', '../data/train/audio/bed/8d5d076d_nohash_0.wav'),
#  (11, '8d8d9855', '../data/train/audio/bed/8d8d9855_nohash_0.wav'),
#  (11, '8d8d9855', '../data/train/audio/bed/8d8d9855_nohash_1.wav'),
#  (11, '8d8d9855', '../data/train/audio/bed/8d8d9855_nohash_2.wav'),
#  (11, '8dd24423', '../data/train/audio/bed/8dd24423_nohash_0.wav'),
#  (11, '8dd24423', '../data/train/audio/bed/8dd24423_nohash_1.wav'),
#  (11, '8e05039f', '../data/train/audio/bed/8e05039f_nohash_0.wav'),
#  (11, '8ea22de7', '../data/train/audio/bed/8ea22de7_nohash_0.wav'),
#  (11, '8eb4a1bf', '../data/train/audio/bed/8eb4a1bf_nohash_0.wav'),
#  (11, '8ec6dab6', '../data/train/audio/bed/8ec6dab6_nohash_0.wav'),
#  (11, '8ec6dab6', '../data/train/audio/bed/8ec6dab6_nohash_1.wav'),
#  (11, '8f3f252c', '../data/train/audio/bed/8f3f252c_nohash_0.wav'),
#  (11, '8f3f252c', '../data/train/audio/bed/8f3f252c_nohash_1.wav'),
#  (11, '8f3f252c', '../data/train/audio/bed/8f3f252c_nohash_2.wav'),
#  (11, '8f4c551f', '../data/train/audio/bed/8f4c551f_nohash_0.wav'),
#  (11, '902258bb', '../data/train/audio/bed/902258bb_nohash_0.wav'),
#  (11, '902258bb', '../data/train/audio/bed/902258bb_nohash_1.wav'),
#  (11, '90b0b91a', '../data/train/audio/bed/90b0b91a_nohash_0.wav'),
#  (11, '91223b83', '../data/train/audio/bed/91223b83_nohash_0.wav'),
#  (11, '918a2473', '../data/train/audio/bed/918a2473_nohash_0.wav'),
#  (11, '919d3c0e', '../data/train/audio/bed/919d3c0e_nohash_0.wav'),
#  (11, '91cdef62', '../data/train/audio/bed/91cdef62_nohash_0.wav'),
#  (11, '91cdef62', '../data/train/audio/bed/91cdef62_nohash_1.wav'),
#  (11, '91cdef62', '../data/train/audio/bed/91cdef62_nohash_2.wav'),
#  (11, '92037d73', '../data/train/audio/bed/92037d73_nohash_0.wav'),
#  (11, '924c1a04', '../data/train/audio/bed/924c1a04_nohash_0.wav'),
#  (11, '924c1a04', '../data/train/audio/bed/924c1a04_nohash_1.wav'),
#  (11, '92a9c5e6', '../data/train/audio/bed/92a9c5e6_nohash_0.wav'),
#  (11, '92b2bf59', '../data/train/audio/bed/92b2bf59_nohash_0.wav'),
#  (11, '92b2bf59', '../data/train/audio/bed/92b2bf59_nohash_1.wav'),
#  (11, '92b2bf59', '../data/train/audio/bed/92b2bf59_nohash_2.wav'),
#  (11, '92e17cc4', '../data/train/audio/bed/92e17cc4_nohash_0.wav'),
#  (11, '92e17cc4', '../data/train/audio/bed/92e17cc4_nohash_1.wav'),
#  (11, '937b433e', '../data/train/audio/bed/937b433e_nohash_0.wav'),
#  (11, '93ec8b84', '../data/train/audio/bed/93ec8b84_nohash_0.wav'),
#  (11, '93ec8b84', '../data/train/audio/bed/93ec8b84_nohash_1.wav'),
#  (11, '94de6a6a', '../data/train/audio/bed/94de6a6a_nohash_0.wav'),
#  (11, '94e6864f', '../data/train/audio/bed/94e6864f_nohash_0.wav'),
#  (11, '94e6864f', '../data/train/audio/bed/94e6864f_nohash_1.wav'),
#  (11, '94e6864f', '../data/train/audio/bed/94e6864f_nohash_2.wav'),
#  (11, '94e6864f', '../data/train/audio/bed/94e6864f_nohash_3.wav'),
#  (11, '94e6864f', '../data/train/audio/bed/94e6864f_nohash_4.wav'),
#  (11, '951cac20', '../data/train/audio/bed/951cac20_nohash_0.wav'),
#  (11, '951cac20', '../data/train/audio/bed/951cac20_nohash_1.wav'),
#  (11, '95218ce8', '../data/train/audio/bed/95218ce8_nohash_0.wav'),
#  (11, '95299b6c', '../data/train/audio/bed/95299b6c_nohash_0.wav'),
#  (11, '953fe1ad', '../data/train/audio/bed/953fe1ad_nohash_0.wav'),
#  (11, '9587481f', '../data/train/audio/bed/9587481f_nohash_0.wav'),
#  (11, '9637f43f', '../data/train/audio/bed/9637f43f_nohash_0.wav'),
#  (11, '9637f43f', '../data/train/audio/bed/9637f43f_nohash_1.wav'),
#  (11, '964e8cfd', '../data/train/audio/bed/964e8cfd_nohash_0.wav'),
#  (11, '96a48d28', '../data/train/audio/bed/96a48d28_nohash_0.wav'),
#  (11, '96ab6565', '../data/train/audio/bed/96ab6565_nohash_0.wav'),
#  (11, '9712cce0', '../data/train/audio/bed/9712cce0_nohash_0.wav'),
#  (11, '9799379a', '../data/train/audio/bed/9799379a_nohash_0.wav'),
#  (11, '9799379a', '../data/train/audio/bed/9799379a_nohash_1.wav'),
#  (11, '97addd88', '../data/train/audio/bed/97addd88_nohash_0.wav'),
#  (11, '97e0c576', '../data/train/audio/bed/97e0c576_nohash_0.wav'),
#  (11, '97e0c576', '../data/train/audio/bed/97e0c576_nohash_1.wav'),
#  (11, '97e0c576', '../data/train/audio/bed/97e0c576_nohash_2.wav'),
#  (11, '97e0c576', '../data/train/audio/bed/97e0c576_nohash_3.wav'),
#  (11, '97f493b9', '../data/train/audio/bed/97f493b9_nohash_0.wav'),
#  (11, '97f4c236', '../data/train/audio/bed/97f4c236_nohash_0.wav'),
#  (11, '981e2a16', '../data/train/audio/bed/981e2a16_nohash_0.wav'),
#  (11, '981e2a16', '../data/train/audio/bed/981e2a16_nohash_1.wav'),
#  (11, '982babaf', '../data/train/audio/bed/982babaf_nohash_0.wav'),
#  (11, '98447c43', '../data/train/audio/bed/98447c43_nohash_0.wav'),
#  (11, '98447c43', '../data/train/audio/bed/98447c43_nohash_1.wav'),
#  (11, '98582fee', '../data/train/audio/bed/98582fee_nohash_0.wav'),
#  (11, '98582fee', '../data/train/audio/bed/98582fee_nohash_1.wav'),
#  (11, '9886d8bf', '../data/train/audio/bed/9886d8bf_nohash_0.wav'),
#  (11, '988e2f9a', '../data/train/audio/bed/988e2f9a_nohash_0.wav'),
#  (11, '988e2f9a', '../data/train/audio/bed/988e2f9a_nohash_1.wav'),
#  (11, '99081f4d', '../data/train/audio/bed/99081f4d_nohash_0.wav'),
#  (11, '997867e7', '../data/train/audio/bed/997867e7_nohash_0.wav'),
#  (11, '99e6cab8', '../data/train/audio/bed/99e6cab8_nohash_0.wav'),
#  (11, '99e6cab8', '../data/train/audio/bed/99e6cab8_nohash_1.wav'),
#  (11, '99fad6a0', '../data/train/audio/bed/99fad6a0_nohash_0.wav'),
#  (11, '99fad6a0', '../data/train/audio/bed/99fad6a0_nohash_1.wav'),
#  (11, '9a356ab9', '../data/train/audio/bed/9a356ab9_nohash_0.wav'),
#  (11, '9a3f97f8', '../data/train/audio/bed/9a3f97f8_nohash_0.wav'),
#  (11, '9a43b64b', '../data/train/audio/bed/9a43b64b_nohash_0.wav'),
#  (11, '9a4d12fd', '../data/train/audio/bed/9a4d12fd_nohash_0.wav'),
#  (11, '9a4d12fd', '../data/train/audio/bed/9a4d12fd_nohash_1.wav'),
#  (11, '9a69672b', '../data/train/audio/bed/9a69672b_nohash_0.wav'),
#  (11, '9a7c1f83', '../data/train/audio/bed/9a7c1f83_nohash_0.wav'),
#  (11, '9a7c1f83', '../data/train/audio/bed/9a7c1f83_nohash_1.wav'),
#  (11, '9aa21fa9', '../data/train/audio/bed/9aa21fa9_nohash_0.wav'),
#  (11, '9aa5439d', '../data/train/audio/bed/9aa5439d_nohash_0.wav'),
#  (11, '9ab86dd0', '../data/train/audio/bed/9ab86dd0_nohash_0.wav'),
#  (11, '9acd0254', '../data/train/audio/bed/9acd0254_nohash_0.wav'),
#  (11, '9b027ecf', '../data/train/audio/bed/9b027ecf_nohash_0.wav'),
#  (11, '9b027ecf', '../data/train/audio/bed/9b027ecf_nohash_1.wav'),
#  (11, '9b3ea809', '../data/train/audio/bed/9b3ea809_nohash_0.wav'),
#  (11, '9b402bc2', '../data/train/audio/bed/9b402bc2_nohash_0.wav'),
#  (11, '9b402bc2', '../data/train/audio/bed/9b402bc2_nohash_1.wav'),
#  (11, '9b5815cd', '../data/train/audio/bed/9b5815cd_nohash_0.wav'),
#  (11, '9b5815cd', '../data/train/audio/bed/9b5815cd_nohash_1.wav'),
#  (11, '9b5815cd', '../data/train/audio/bed/9b5815cd_nohash_2.wav'),
#  (11, '9bea2ac7', '../data/train/audio/bed/9bea2ac7_nohash_0.wav'),
#  (11, '9beccfc8', '../data/train/audio/bed/9beccfc8_nohash_0.wav'),
#  (11, '9c06a3f3', '../data/train/audio/bed/9c06a3f3_nohash_0.wav'),
#  (11, '9c59dd28', '../data/train/audio/bed/9c59dd28_nohash_0.wav'),
#  (11, '9ce7a419', '../data/train/audio/bed/9ce7a419_nohash_0.wav'),
#  (11, '9d050657', '../data/train/audio/bed/9d050657_nohash_0.wav'),
#  (11, '9d050657', '../data/train/audio/bed/9d050657_nohash_1.wav'),
#  (11, '9d4bab4f', '../data/train/audio/bed/9d4bab4f_nohash_0.wav'),
#  (11, '9d8ac38b', '../data/train/audio/bed/9d8ac38b_nohash_0.wav'),
#  (11, '9dc1889e', '../data/train/audio/bed/9dc1889e_nohash_0.wav'),
#  (11, '9e075bf1', '../data/train/audio/bed/9e075bf1_nohash_0.wav'),
#  (11, '9e2ce5e3', '../data/train/audio/bed/9e2ce5e3_nohash_0.wav'),
#  (11, '9e42ae25', '../data/train/audio/bed/9e42ae25_nohash_0.wav'),
#  (11, '9e46cfa1', '../data/train/audio/bed/9e46cfa1_nohash_0.wav'),
#  (11, '9e6bb505', '../data/train/audio/bed/9e6bb505_nohash_0.wav'),
#  (11, '9e6bb505', '../data/train/audio/bed/9e6bb505_nohash_1.wav'),
#  (11, '9efe5140', '../data/train/audio/bed/9efe5140_nohash_0.wav'),
#  (11, '9efe5140', '../data/train/audio/bed/9efe5140_nohash_1.wav'),
#  (11, '9f63152b', '../data/train/audio/bed/9f63152b_nohash_0.wav'),
#  (11, '9f869f70', '../data/train/audio/bed/9f869f70_nohash_0.wav'),
#  (11, '9ff1b8b6', '../data/train/audio/bed/9ff1b8b6_nohash_0.wav'),
#  (11, '9ff2d2f4', '../data/train/audio/bed/9ff2d2f4_nohash_0.wav'),
#  (11, 'a108341b', '../data/train/audio/bed/a108341b_nohash_0.wav'),
#  (11, 'a16b3102', '../data/train/audio/bed/a16b3102_nohash_0.wav'),
#  (11, 'a16b3102', '../data/train/audio/bed/a16b3102_nohash_1.wav'),
#  (11, 'a19452d5', '../data/train/audio/bed/a19452d5_nohash_0.wav'),
#  (11, 'a19452d5', '../data/train/audio/bed/a19452d5_nohash_1.wav'),
#  (11, 'a19452d5', '../data/train/audio/bed/a19452d5_nohash_2.wav'),
#  (11, 'a1a59b72', '../data/train/audio/bed/a1a59b72_nohash_0.wav'),
#  (11, 'a1c63f25', '../data/train/audio/bed/a1c63f25_nohash_0.wav'),
#  (11, 'a1cff772', '../data/train/audio/bed/a1cff772_nohash_0.wav'),
#  (11, 'a24582a0', '../data/train/audio/bed/a24582a0_nohash_0.wav'),
#  (11, 'a24582a0', '../data/train/audio/bed/a24582a0_nohash_1.wav'),
#  (11, 'a2473d62', '../data/train/audio/bed/a2473d62_nohash_0.wav'),
#  (11, 'a2473d62', '../data/train/audio/bed/a2473d62_nohash_1.wav'),
#  (11, 'a24cf51c', '../data/train/audio/bed/a24cf51c_nohash_0.wav'),
#  (11, 'a24cf51c', '../data/train/audio/bed/a24cf51c_nohash_1.wav'),
#  (11, 'a2b16113', '../data/train/audio/bed/a2b16113_nohash_0.wav'),
#  (11, 'a2b16113', '../data/train/audio/bed/a2b16113_nohash_1.wav'),
#  (11, 'a2b16113', '../data/train/audio/bed/a2b16113_nohash_2.wav'),
#  (11, 'a2b16113', '../data/train/audio/bed/a2b16113_nohash_3.wav'),
#  (11, 'a2fefcb4', '../data/train/audio/bed/a2fefcb4_nohash_0.wav'),
#  (11, 'a3255f5c', '../data/train/audio/bed/a3255f5c_nohash_0.wav'),
#  (11, 'a3255f5c', '../data/train/audio/bed/a3255f5c_nohash_1.wav'),
#  (11, 'a3255f5c', '../data/train/audio/bed/a3255f5c_nohash_2.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_0.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_1.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_2.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_3.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_4.wav'),
#  (11, 'a331d9cb', '../data/train/audio/bed/a331d9cb_nohash_5.wav'),
#  (11, 'a3502f15', '../data/train/audio/bed/a3502f15_nohash_0.wav'),
#  (11, 'a4baac4e', '../data/train/audio/bed/a4baac4e_nohash_0.wav'),
#  (11, 'a4baac4e', '../data/train/audio/bed/a4baac4e_nohash_1.wav'),
#  (11, 'a4c938ce', '../data/train/audio/bed/a4c938ce_nohash_0.wav'),
#  (11, 'a4c938ce', '../data/train/audio/bed/a4c938ce_nohash_1.wav'),
#  (11, 'a4e8a997', '../data/train/audio/bed/a4e8a997_nohash_0.wav'),
#  (11, 'a4e8a997', '../data/train/audio/bed/a4e8a997_nohash_1.wav'),
#  (11, 'a50a98d2', '../data/train/audio/bed/a50a98d2_nohash_0.wav'),
#  (11, 'a518d1cf', '../data/train/audio/bed/a518d1cf_nohash_0.wav'),
#  (11, 'a518d1cf', '../data/train/audio/bed/a518d1cf_nohash_1.wav'),
#  (11, 'a518d1cf', '../data/train/audio/bed/a518d1cf_nohash_2.wav'),
#  (11, 'a527cb3c', '../data/train/audio/bed/a527cb3c_nohash_0.wav'),
#  (11, 'a527cb3c', '../data/train/audio/bed/a527cb3c_nohash_1.wav'),
#  (11, 'a5609cce', '../data/train/audio/bed/a5609cce_nohash_0.wav'),
#  (11, 'a5d485dc', '../data/train/audio/bed/a5d485dc_nohash_0.wav'),
#  (11, 'a60a09cf', '../data/train/audio/bed/a60a09cf_nohash_0.wav'),
#  (11, 'a6285644', '../data/train/audio/bed/a6285644_nohash_0.wav'),
#  (11, 'a84dee7b', '../data/train/audio/bed/a84dee7b_nohash_0.wav'),
#  (11, 'a8cb6dda', '../data/train/audio/bed/a8cb6dda_nohash_0.wav'),
#  (11, 'a8cb6dda', '../data/train/audio/bed/a8cb6dda_nohash_1.wav'),
#  (11, 'a8cb6dda', '../data/train/audio/bed/a8cb6dda_nohash_2.wav'),
#  (11, 'a8e25ebb', '../data/train/audio/bed/a8e25ebb_nohash_0.wav'),
#  (11, 'a8ee11c7', '../data/train/audio/bed/a8ee11c7_nohash_0.wav'),
#  (11, 'a8f45bdc', '../data/train/audio/bed/a8f45bdc_nohash_0.wav'),
#  (11, 'a8f45bdc', '../data/train/audio/bed/a8f45bdc_nohash_1.wav'),
#  (11, 'a902ce9b', '../data/train/audio/bed/a902ce9b_nohash_0.wav'),
#  (11, 'a996cf66', '../data/train/audio/bed/a996cf66_nohash_0.wav'),
#  (11, 'a996cf66', '../data/train/audio/bed/a996cf66_nohash_1.wav'),
#  (11, 'a9abc695', '../data/train/audio/bed/a9abc695_nohash_0.wav'),
#  (11, 'a9abc695', '../data/train/audio/bed/a9abc695_nohash_1.wav'),
#  (11, 'aa233654', '../data/train/audio/bed/aa233654_nohash_0.wav'),
#  (11, 'aa48c94a', '../data/train/audio/bed/aa48c94a_nohash_0.wav'),
#  (11, 'aa48c94a', '../data/train/audio/bed/aa48c94a_nohash_1.wav'),
#  (11, 'ab353673', '../data/train/audio/bed/ab353673_nohash_0.wav'),
#  (11, 'ab5ae445', '../data/train/audio/bed/ab5ae445_nohash_0.wav'),
#  (11, 'ab5ae445', '../data/train/audio/bed/ab5ae445_nohash_1.wav'),
#  (11, 'ab5b211a', '../data/train/audio/bed/ab5b211a_nohash_0.wav'),
#  ...]

# %% [markdown]
# Let me introduce pythonic datagenerator.
# It is just a python/numpy/... function **without tf** that yields dicts such that
# ```
# {
#   'x': np.array(...),
#   'str_key': np.string_(...),
#   'label': np.int32(...),
# }
# ```
#
# Be sure, every value in this dict has `.dtype` method.

# %%
import numpy as np
from scipy.io import wavfile

def data_generator(data, params, mode='train'):
    def generator():
        if mode == 'train':
            np.random.shuffle(data)
        # Feel free to add any augmentation
        for (label_id, uid, fname) in data:
            try:
                _, wav = wavfile.read(fname)
                wav = wav.astype(np.float32) / np.iinfo(np.int16).max

                L = 16000  # be aware, some files are shorter than 1 sec!
                if len(wav) < L:
                    continue
                # let's generate more silence!
                samples_per_file = 1 if label_id != name2id['silence'] else 20
                for _ in range(samples_per_file):
                    if len(wav) > L:
                        beg = np.random.randint(0, len(wav) - L)
                    else:
                        beg = 0
                    yield dict(
                        target=np.int32(label_id),
                        wav=wav[beg: beg + L],
                    )
            except Exception as err:
                print(err, label_id, uid, fname)

    return generator

# %% [markdown]
# Suppose, we have spectrograms and want to write feature extractor that produces logits.
#
#
# Let's write some simple net, treat sound as a picture.
#
#
# **Spectrograms** (input x) have shape `(batch_size, time_frames, freq_bins, 2)`.
#
# **Logits** is a tensor with shape `(batch_size, num_classes)`.

# %%
import tensorflow as tf
from tensorflow.contrib import layers

def baseline(x, params, is_training):
    x = layers.batch_norm(x, is_training=is_training)
    for i in range(4):
        x = layers.conv2d(
            x, 16 * (2 ** i), 3, 1,
            activation_fn=tf.nn.elu,
            normalizer_fn=layers.batch_norm if params.use_batch_norm else None,
            normalizer_params={'is_training': is_training}
        )
        x = layers.max_pool2d(x, 2, 2)

    # just take two kind of pooling and then mix them, why not :)
    mpool = tf.reduce_max(x, axis=[1, 2], keep_dims=True)
    apool = tf.reduce_mean(x, axis=[1, 2], keep_dims=True)

    x = 0.5 * (mpool + apool)
    # we can use conv2d 1x1 instead of dense
    x = layers.conv2d(x, 128, 1, 1, activation_fn=tf.nn.elu)
    x = tf.nn.dropout(x, keep_prob=params.keep_prob if is_training else 1.0)
    
    # again conv2d 1x1 instead of dense layer
    logits = layers.conv2d(x, params.num_classes, 1, 1, activation_fn=None)
    return tf.squeeze(logits, [1, 2])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9bfa8fa3d61a> in <module>
#       1 import tensorflow as tf
# ----> 2 from tensorflow.contrib import layers
#       3
#       4 def baseline(x, params, is_training):
#       5     x = layers.batch_norm(x, is_training=is_training)
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %% [markdown]
# We need to write a model handler for three regimes:
# - train
# - eval
# - predict
#
# Loss function, train_op, additional metrics and summaries should be defined.
#
# Also, we need to convert sound waveform into spectrograms (we could do it with numpy/scipy/librosa in data generator, but TF has new signal processing API)

# %%
from tensorflow.contrib import signal

# features is a dict with keys: tensors from our datagenerator
# labels also were in features, but excluded in generator_input_fn by target_key

def model_handler(features, labels, mode, params, config):
    # Im really like to use make_template instead of variable_scopes and re-usage
    extractor = tf.make_template(
        'extractor', baseline,
        create_scope_now_=True,
    )
    # wav is a waveform signal with shape (16000, )
    wav = features['wav']
    # we want to compute spectograms by means of short time fourier transform:
    specgram = signal.stft(
        wav,
        400,  # 16000 [samples per second] * 0.025 [s] -- default stft window frame
        160,  # 16000 * 0.010 -- default stride
    )
    # specgram is a complex tensor, so split it into abs and phase parts:
    phase = tf.angle(specgram) / np.pi
    # log(1 + abs) is a default transformation for energy units
    amp = tf.log1p(tf.abs(specgram))
    
    x = tf.stack([amp, phase], axis=3) # shape is [bs, time, freq_bins, 2]
    x = tf.to_float(x)  # we want to have float32, not float64

    logits = extractor(x, params, mode == tf.estimator.ModeKeys.TRAIN)

    if mode == tf.estimator.ModeKeys.TRAIN:
        loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))
        # some lr tuner, you could use move interesting functions
        def learning_rate_decay_fn(learning_rate, global_step):
            return tf.train.exponential_decay(
                learning_rate, global_step, decay_steps=10000, decay_rate=0.99)

        train_op = tf.contrib.layers.optimize_loss(
            loss=loss,
            global_step=tf.contrib.framework.get_global_step(),
            learning_rate=params.learning_rate,
            optimizer=lambda lr: tf.train.MomentumOptimizer(lr, 0.9, use_nesterov=True),
            learning_rate_decay_fn=learning_rate_decay_fn,
            clip_gradients=params.clip_gradients,
            variables=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES))

        specs = dict(
            mode=mode,
            loss=loss,
            train_op=train_op,
        )

    if mode == tf.estimator.ModeKeys.EVAL:
        prediction = tf.argmax(logits, axis=-1)
        acc, acc_op = tf.metrics.mean_per_class_accuracy(
            labels, prediction, params.num_classes)
        loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))
        specs = dict(
            mode=mode,
            loss=loss,
            eval_metric_ops=dict(
                acc=(acc, acc_op),
            )
        )

    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            'label': tf.argmax(logits, axis=-1),  # for probability just take tf.nn.softmax()
            'sample': features['sample'], # it's a hack for simplicity
        }
        specs = dict(
            mode=mode,
            predictions=predictions,
        )
    return tf.estimator.EstimatorSpec(**specs)


def create_model(config=None, hparams=None):
    return tf.estimator.Estimator(
        model_fn=model_handler,
        config=config,
        params=hparams,
    )

# %% [markdown]
# Define some params. Move model hyperparams (optimizer, extractor, num of layers, activation fn, ...) here

# %%
params=dict(
    seed=2018,
    batch_size=64,
    keep_prob=0.5,
    learning_rate=1e-3,
    clip_gradients=15.0,
    use_batch_norm=True,
    num_classes=len(POSSIBLE_LABELS),
)

# hparams = tf.contrib.training.HParams(**params)
hparams = tf.training.HParams(**params)
os.makedirs(os.path.join(OUTDIR, 'eval'), exist_ok=True)
model_dir = OUTDIR

run_config = tf.contrib.learn.RunConfig(model_dir=model_dir)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0692a77066e1> in <module>
#      10
#      11 # hparams = tf.contrib.training.HParams(**params)
# ---> 12 hparams = tf.training.HParams(**params)
#      13 os.makedirs(os.path.join(OUTDIR, 'eval'), exist_ok=True)
#      14 model_dir = OUTDIR
#
# AttributeError: module 'tensorflow' has no attribute 'training'

# %% [markdown]
# **Let's run training!**

# %%
# it's a magic function :)
from tensorflow.contrib.learn.python.learn.learn_io.generator_io import generator_input_fn
            
train_input_fn = generator_input_fn(
    x=data_generator(trainset, hparams, 'train'),
    target_key='target',  # you could leave target_key in features, so labels in model_handler will be empty
    batch_size=hparams.batch_size, shuffle=True, num_epochs=None,
    queue_capacity=3 * hparams.batch_size + 10, num_threads=1,
)

val_input_fn = generator_input_fn(
    x=data_generator(valset, hparams, 'val'),
    target_key='target',
    batch_size=hparams.batch_size, shuffle=True, num_epochs=None,
    queue_capacity=3 * hparams.batch_size + 10, num_threads=1,
)
            

def _create_my_experiment(run_config, hparams):
    exp = tf.contrib.learn.Experiment(
        estimator=create_model(config=run_config, hparams=hparams),
        train_input_fn=train_input_fn,
        eval_input_fn=val_input_fn,
        train_steps=10000, # just randomly selected params
        eval_steps=200,  # read source code for steps-epochs ariphmetics
        train_steps_per_iteration=1000,
    )
    return exp

tf.contrib.learn.learn_runner.run(
    experiment_fn=_create_my_experiment,
    run_config=run_config,
    schedule="continuous_train_and_eval",
    hparams=hparams)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2d7b0a4f0362> in <module>()
#       3
#       4 train_input_fn = generator_input_fn(
# ----> 5     x=data_generator(trainset, hparams, 'train'),
#       6     target_key='target',  # you could leave target_key in features, so labels in model_handler will be empty
#       7     batch_size=hparams.batch_size, shuffle=True, num_epochs=None,
#
# NameError: name 'trainset' is not defined

# %% [markdown]
# While it trains (~10-20min on i5 + 1080), you could start tensorboard on model_dir and see live chart like this
#
# ![Tensorboard](https://pp.userapi.com/c841329/v841329524/3db60/fdNDyRMJHMQ.jpg)
#
#
# Now we want to predict testset and make submission file.
#
# 1. Create datagenerator and input_function
# 2. Load model
# 3. Iterate over predictions and store results

# %%
from tqdm import tqdm
# now we want to predict!
paths = glob(os.path.join(DATADIR, 'test/audio/*wav'))

def test_data_generator(data):
    def generator():
        for path in data:
            _, wav = wavfile.read(path)
            wav = wav.astype(np.float32) / np.iinfo(np.int16).max
            fname = os.path.basename(path)
            yield dict(
                sample=np.string_(fname),
                wav=wav,
            )

    return generator

test_input_fn = generator_input_fn(
    x=test_data_generator(paths),
    batch_size=hparams.batch_size, 
    shuffle=False, 
    num_epochs=1,
    queue_capacity= 10 * hparams.batch_size, 
    num_threads=1,
)

model = create_model(config=run_config, hparams=hparams)
it = model.predict(input_fn=test_input_fn)


# last batch will contain padding, so remove duplicates
submission = dict()
for t in tqdm(it):
    fname, label = t['sample'].decode(), id2name[t['label']]
    submission[fname] = label

with open(os.path.join(model_dir, 'submission.csv'), 'w') as fout:
    fout.write('fname,label\n')
    for fname, label in submission.items():
        fout.write('{},{}\n'.format(fname, label))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-d9a39891bf10> in <module>()
#      22     num_epochs=1,
#      23     queue_capacity= 10 * hparams.batch_size,
# ---> 24     num_threads=1,
#      25 )
#      26
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/learn_io/generator_io.py in generator_input_fn(x, target_key, batch_size, num_epochs, shuffle, queue_capacity, num_threads, pad_value)
#      93     raise TypeError(
#      94         'x() must be generator; got {}'.format(type(generator).__name__))
# ---> 95   data = next(generator)
#      96   if not isinstance(data, dict):
#      97     raise TypeError('x() must yield dict; got {}'.format(type(data).__name__))
#
# StopIteration:

# %% [markdown]
# ## About tf.Estimators
#
# **Pros**:
# - no need to control Session
# - datagenerator feeds model via queues without explicit queue coding :)
# - you could naturaly export models into production
#
# **Cons**:
# - it's very hard to debug computational graph (use `tf.add_check_numerics()` and `tf.Print` in case of problems)
# - boilerplate code
# - need to read source code for making interesting things
#
#
# **Conclusion**:
# Estimator is a nice abstraction with some boilerplate code :)
#
#
# ## About Speech Recognition Challenge:
#
# You could start from this end-to-end ipynb, improving several functions for much better results.
#
#
#
# May the gradient flow be with you.
